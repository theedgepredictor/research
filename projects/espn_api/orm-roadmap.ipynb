# %% [markdown]
# ## Roadmap
#
# 1. Define Proof of Concept (POC) design
#     1. What classes are we going to use?
#     2. What are the requirements?
#     3. Finish out sport/league pair mapper
#     4. Add basic sport selector to the ORM
# 2. Build out testing suite and documentation for POC
# 3. Run POC and verify results
# 4. Define Publish to Pypi pipeline

# %% [markdown]
# ## 1. Define Proof of Concept (POC) design
#
# **What classes are we going to use?**
# - Base
# - Sport
# - League
# - Teams
# - Venues
# - Scoreboard
#
# **What are the requirements?**
#
#
# **Finish out sport/league pair mapper**
#
#
# **Add basic sport selector to the ORM**
#
# ## 2. Create sample data collection pipeline for local
# - For the last 2 seasons lets get all the events
# - For NFL lets get all the teams for each season
# - For each of these events can we build out aggregate metrics

# %%
pip install -U espn-api-orm
# Out:
# Requirement already satisfied: espn-api-orm in c:\users\charl\desktop\git\tep-research\.venv\lib\site-packages (0.0.7)
# Requirement already satisfied: pydantic>2.0.0 in c:\users\charl\desktop\git\tep-research\.venv\lib\site-packages (from espn-api-orm) (2.6.1)
# Requirement already satisfied: requests>=2.31.0 in c:\users\charl\desktop\git\tep-research\.venv\lib\site-packages (from espn-api-orm) (2.31.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\charl\desktop\git\tep-research\.venv\lib\site-packages (from pydantic>2.0.0->espn-api-orm) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\charl\desktop\git\tep-research\.venv\lib\site-packages (from pydantic>2.0.0->espn-api-orm) (2.16.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\charl\desktop\git\tep-research\.venv\lib\site-packages (from pydantic>2.0.0->espn-api-orm) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\charl\desktop\git\tep-research\.venv\lib\site-packages (from requests>=2.31.0->espn-api-orm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\charl\desktop\git\tep-research\.venv\lib\site-packages (from requests>=2.31.0->espn-api-orm) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\charl\desktop\git\tep-research\.venv\lib\site-packages (from requests>=2.31.0->espn-api-orm) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\charl\desktop\git\tep-research\.venv\lib\site-packages (from requests>=2.31.0->espn-api-orm) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Create SportLeague Class

# %%
from espn_api_orm.consts import ESPNSportLeagueTypes, ESPNSportTypes
from espn_api_orm.league.api import ESPNLeagueAPI


class SportLeague:
    def __init__(self, sport_league: ESPNSportLeagueTypes, autofill=False):
        self.sport_league = sport_league
        self.sport = ESPNSportTypes(sport_league.value.split('/')[0])
        self.league_str = sport_league.value.split('/')[1]
        self.api = ESPNLeagueAPI(self.sport, self.league_str)
        self.is_active = self.api.is_active()
        if not self.is_active:
            print(f"""{self.sport.value.upper()}/{self.league_str.upper()} is not active turn autofill to True to still get results.""")
        self.league_obj = None
        self.seasons = None
        self.first_season = None
        self.current_season = None
        self.franchises = None
        self.odds_providers = None
        if self.is_active or autofill:
            self._autofill()
    
    def _autofill(self):
        self.league_obj = self.api.get_league()
        self.seasons = self.api.get_seasons()
        self.first_season = self.api.get_first_season(return_values=True)
        self.current_season = self.api.get_current_season(return_values=True)
        self.franchises = self.api.get_franchises()
        self.odds_providers = self.api.get_odds_providers()
    
    def __str__(self):
        return f"{self.sport.value.upper()}/{self.league_str.upper()} is " + ("active" if self.is_active else "not active")
    
    def __repr__(self):
        return self.__str__()

sport_league = SportLeague(ESPNSportLeagueTypes.FOOTBALL_NFL, autofill=True)
sport_league
# Out:
# FOOTBALL/NFL is not active turn autofill to True to still get results.
# FOOTBALL/NFL is not active

# %% [markdown]
# ## Create SportTeamSeason Class
#
# - This will include the teams schedule for easy linking to events

# %%
from espn_api_orm.consts import ESPNSportTypes
from espn_api_orm.team.api import ESPNTeamAPI

class SportTeamSeason:
    def __init__(self, sport: ESPNSportTypes, league: str, season: int, team_id: int, autofill=False):
        self.sport = sport
        self.league = league
        self.season = season
        self.team_id = team_id
        self.api = ESPNTeamAPI(self.sport, self.league, self.season, self.team_id)
        self.team = self.api.get_team()        
        self.event_ids = None
        self.record = None
        self.news = None
        self.depthchart = None
        self.statistics = None

        if autofill:
            self.refresh()

    def __str__(self):
        return f"{self.season} - {self.team.displayName}"
    
    def __repr__(self):
        return self.__str__()

    def _autofill(self):
        self.event_ids = self.api.get_events()
        self.record = self.api.get_record()
        self.news = self.api.get_news()
        self.depthchart = self.api.get_depthchart()
        self.statistics = self.api.get_statistics()

    def refresh(self):
        return self._autofill()
    
class SportTeamEvent:
    def __init__(self, sport: ESPNSportTypes, league: str, season: int, event_id: int, team_id: int, autofill=False):
        self.sport = sport
        self.league = league
        self.season = season
        self.event_id = event_id
        self.team_id = team_id

# %% [markdown]
# ## Create SportEvent Class
#
# The big boy class. We will have to define loaders to be selected for what data will get autofilled vs what we can add after the group has completed

# %%
from espn_api_orm.event.api import ESPNEventAPI
from espn_api_orm.event.schema import Event

class SportEvent:
    '''
    Allows for new event collection from the event_id or pass in an existing ESPNEvent object
    '''
    def __init__(self, sport: ESPNSportTypes, league: str, season: int, event_id: int = None, event: Event = None, autofill=False):
        self.sport = sport
        self.league = league
        self.season = season
        self.event = None
        if event:
            self.event_id = event.id
        else:
            self.event_id = event_id
        self.api = ESPNEventAPI(self.sport, self.league, self.event_id)
        self.event = self.api.get_event() if event is None else event
        self.odds = None
        self.officials = None
        self.prediction = None
        if autofill:
            self.refresh()

    def __str__(self):
        return f"{self.season} - {self.event.name}"
    
    def __repr__(self):
        return self.__str__()

    def _autofill(self):
        self.odds = self.api.get_odds()
        self.officials = self.api.get_game_officials()
        self.prediction = self.api.get_prediction()

    def refresh(self):
        return self._autofill()

# %% [markdown]
# ## Create SportSeason Class

# %%
from espn_api_orm.consts import ESPNSportTypes, ESPNSportSeasonTypes
from espn_api_orm.calendar.api import ESPNCalendarAPI
from espn_api_orm.season.api import ESPNSeasonAPI
from espn_api_orm.team.api import ESPNTeamAPI
from espn_api_orm.scoreboard.api import ESPNScoreboardAPI
import datetime
from enum import Enum

## Create a load type enum for sport season
class SportSeasonLoadType(Enum):
    EVENTS = 1
    TEAMS = 2
    BOTH = 3
    NONE = 4

class SportSeason:
    def __init__(self, sport_league: SportLeague, season: int, load_type: SportSeasonLoadType = SportSeasonLoadType.NONE):
        self.sport_league = sport_league
        self.sport = ESPNSportTypes(sport_league.sport)
        self.league_str = sport_league.league_str
        self.season = season
        self.load_type = load_type
        self.api = ESPNSeasonAPI(self.sport, self.league_str, self.season)
        self.types = self.api.get_valid_types()
        self.calendar = self._load_calendar()
        self.teams = None
        self.events = None
        self.refresh()

    def __str__(self):
        return f"{self.sport.value.upper()}/{self.league_str.upper()} - {self.season}"
    
    def __repr__(self):
        return self.__str__()

    def _load_calendar(self):
        calendar_api = ESPNCalendarAPI(self.sport, self.league_str, self.season)
        return calendar_api.get_calendar_sections(self.types)

    def _load_teams(self):
        return [SportTeamSeason(self.sport, self.league_str, self.season, team_id, autofill=True) for team_id in self.api.get_team_ids()[0:3]]

    def _load_events(self):
        ## events for each calendar section
        ## use the scoreboard api to collect the espn sport event
        events = []
        #date_events = {}
        scoreboard_api = ESPNScoreboardAPI(self.sport, self.league_str)
        calendar_dates = []
        ## loop through each calendar section and get unique dates
        for calendar_section in self.calendar:
            calendar_dates.extend(calendar_section.dates)
        
        calendar_dates = list(set(calendar_dates))
        calendar_dates = sorted(calendar_dates)

        
        for calendar_date in calendar_dates[0:2]:
            date = datetime.datetime.strftime(calendar_date, "%Y%m%d")
            scoreboard = scoreboard_api.get_scoreboard(dates = date)
            #date_events[date] = []
            for event in scoreboard.events:
                sport_event = SportEvent(self.sport, self.league_str, self.season, event=event, autofill=True)
                events.append(sport_event)
                #date_events[date].append(sport_event.event_id)
        return events

    def refresh(self):
        if self.load_type == SportSeasonLoadType.BOTH:
            self.teams = self._load_teams()
            self.events = self._load_events()
        elif self.load_type == SportSeasonLoadType.EVENTS:
            self.events = self._load_events()
        elif self.load_type == SportSeasonLoadType.TEAMS:
            self.teams = self._load_teams()
        else:
            self.events = None
            self.teams = None

        
current_season = sport_league.current_season
sport_season = SportSeason(sport_league, current_season-2, load_type=SportSeasonLoadType.EVENTS)
# Out:
# https://site.api.espn.com/apis/site/v2/sports/football/nfl/scoreboard?dates=20220804&limit=1000
# https://site.api.espn.com/apis/site/v2/sports/football/nfl/scoreboard?dates=20220811&limit=1000

# %%
# Out:
# {'id': 401437964,
#  'uid': 's:20~l:28~e:401437964',
#  'date': datetime.datetime(2022, 8, 5, 0, 0, tzinfo=TzInfo(UTC)),
#  'name': 'Jacksonville Jaguars at Las Vegas Raiders',
#  'shortName': 'JAX VS LV',
#  'season': Season(year=2022, type=1, slug='preseason'),
#  'competitions': [Competition(id=401437964, uid='s:20~l:28~e:401437964~c:401437964', date=datetime.datetime(2022, 8, 5, 0, 0, tzinfo=TzInfo(UTC)), attendance=17129, type=Type(id='1', abbreviation='STD'), timeValid=True, neutralSite=True, conferenceCompetition=False, playByPlayAvailable=True, recent=False, venue=Venue(ref=None, id=3718, fullName='Tom Benson Hall of Fame Stadium', address=Address(city='Canton', state='OH', zipCode=None), capacity=None, grass=None, indoor=False, images=None), competitors=[Competitor(id=13, uid='s:20~l:28~t:13', type='team', order=0, homeAway='home', winner=True, team=Team(ref=None, id=13, guid=None, uid='s:20~l:28~t:13', alternateIds=None, slug=None, location='Las Vegas', name='Raiders', nickname=None, abbreviation='LV', displayName='Las Vegas Raiders', shortDisplayName='Raiders', color='000000', alternateColor='a5acaf', isActive=True, isAllStar=None, logo='https://a.espncdn.com/i/teamlogos/nfl/500/scoreboard/lv.png', logos=None, links=[Link(language=None, rel=['clubhouse', 'desktop', 'team'], href='https://www.espn.com/nfl/team/_/name/lv/las-vegas-raiders', text='Clubhouse', shortText=None, isExternal=False, isPremium=False), Link(language=None, rel=['roster', 'desktop', 'team'], href='https://www.espn.com/nfl/team/roster/_/name/lv/las-vegas-raiders', text='Roster', shortText=None, isExternal=False, isPremium=False), Link(language=None, rel=['stats', 'desktop', 'team'], href='https://www.espn.com/nfl/team/stats/_/name/lv/las-vegas-raiders', text='Statistics', shortText=None, isExternal=False, isPremium=False), Link(language=None, rel=['schedule', 'desktop', 'team'], href='https://www.espn.com/nfl/team/schedule/_/name/lv', text='Schedule', shortText=None, isExternal=False, isPremium=False)], record=None, oddsRecords=None, athletes=None, groups=None, ranks=None, statistics=None, leaders=None, injuries=None, notes=None, againstTheSpreadRecords=None, franchise=None, events=None, college=None, venue=Venue(ref=None, id=6501, fullName=None, address=None, capacity=None, grass=None, indoor=None, images=None), conferenceId=None), score='27', linescores=[Linescore(value=6.0), Linescore(value=14.0), Linescore(value=0.0), Linescore(value=7.0)], statistics=[], leaders=[], curatedRank=None, records=[Record(name='overall', abbreviation='Game', type='total', summary='1-0'), Record(name='Home', abbreviation=None, type='home', summary='1-0'), Record(name='Road', abbreviation=None, type='road', summary='0-0')]), Competitor(id=30, uid='s:20~l:28~t:30', type='team', order=1, homeAway='away', winner=False, team=Team(ref=None, id=30, guid=None, uid='s:20~l:28~t:30', alternateIds=None, slug=None, location='Jacksonville', name='Jaguars', nickname=None, abbreviation='JAX', displayName='Jacksonville Jaguars', shortDisplayName='Jaguars', color='00839C', alternateColor='d7a22a', isActive=True, isAllStar=None, logo='https://a.espncdn.com/i/teamlogos/nfl/500/scoreboard/jax.png', logos=None, links=[Link(language=None, rel=['clubhouse', 'desktop', 'team'], href='https://www.espn.com/nfl/team/_/name/jax/jacksonville-jaguars', text='Clubhouse', shortText=None, isExternal=False, isPremium=False), Link(language=None, rel=['roster', 'desktop', 'team'], href='https://www.espn.com/nfl/team/roster/_/name/jax/jacksonville-jaguars', text='Roster', shortText=None, isExternal=False, isPremium=False), Link(language=None, rel=['stats', 'desktop', 'team'], href='https://www.espn.com/nfl/team/stats/_/name/jax/jacksonville-jaguars', text='Statistics', shortText=None, isExternal=False, isPremium=False), Link(language=None, rel=['schedule', 'desktop', 'team'], href='https://www.espn.com/nfl/team/schedule/_/name/jax', text='Schedule', shortText=None, isExternal=False, isPremium=False)], record=None, oddsRecords=None, athletes=None, groups=None, ranks=None, statistics=None, leaders=None, injuries=None, notes=None, againstTheSpreadRecords=None, franchise=None, events=None, college=None, venue=Venue(ref=None, id=3712, fullName=None, address=None, capa ...
#  'links': [Link(language='en-US', rel=['summary', 'desktop', 'event'], href='https://www.espn.com/nfl/game/_/gameId/401437964/jaguars-raiders', text='Gamecast', shortText='Gamecast', isExternal=False, isPremium=False),
#   Link(language='en-US', rel=['boxscore', 'desktop', 'event'], href='https://www.espn.com/nfl/boxscore/_/gameId/401437964', text='Box Score', shortText='Box Score', isExternal=False, isPremium=False),
#   Link(language='en-US', rel=['pbp', 'desktop', 'event'], href='https://www.espn.com/nfl/playbyplay/_/gameId/401437964', text='Play-by-Play', shortText='Play-by-Play', isExternal=False, isPremium=False),
#   Link(language='en-US', rel=['recap', 'desktop', 'event'], href='https://www.espn.com/nfl/recap?gameId=401437964', text='Recap', shortText='Recap', isExternal=False, isPremium=False)],
#  'status': Status(clock=0.0, displayClock='0:00', period=4, type=Type(id='3', name='STATUS_FINAL', state='post', completed=True, description='Final', detail='Final', shortDetail='Final'))}

# %%
e = sport_season.events[0].event

def flatten(event):
    dict_event = event.__dict__
    is_postseason = int(event['season']['type']) == 3
    is_finished = int(dict_event['status'].type.id) == 3

    return {
        'id': dict_event['id'],
        'uid': dict_event['uid'],
        'date': dict_event['date'],
        'name': dict_event['name'],
        'shortName': dict_event['shortName'],
        'season': dict_event['season'].year,
        #'competitions': dict_event['competitions'],
        #'links': dict_event['links'],
        'is_finished': 
    }

flatten(e)
# Out:
# {'id': 401437964,
#  'uid': 's:20~l:28~e:401437964',
#  'date': datetime.datetime(2022, 8, 5, 0, 0, tzinfo=TzInfo(UTC)),
#  'name': 'Jacksonville Jaguars at Las Vegas Raiders',
#  'shortName': 'JAX VS LV',
#  'season': Season(year=2022, type=1, slug='preseason'),
#  'status': Status(clock=0.0, displayClock='0:00', period=4, type=Type(id='3', name='STATUS_FINAL', state='post', completed=True, description='Final', detail='Final', shortDetail='Final'))}

# %%
# import espn-api-orm and the LeagueAPI and the VenueAPI
import json
import os
from espn_api_orm.league.api import ESPNLeagueAPI
from espn_api_orm.venue.api import ESPNVenueAPI
from espn_api_orm.consts import ESPNSportLeagueTypes
import re
from geopy.geocoders import Nominatim, ArcGIS
import h3
import time
import requests
import datetime

def get_json_file(path):
    try:
        with open(path, 'r') as file:
            return json.load(file)
    except Exception as e:
        return {}

# Function to save sport league file
def put_json_file(path, data):
    with open(path, 'w') as file:
        json.dump(data, file, indent=4)


def make_geocoding_address_string(name, address):
    items = [name, address.city, address.state, address.zipCode]
    items = list(filter(None, items))
    geocoding_address = ', '.join(items)
    return geocoding_address

def get_elevations(lats, lons, n=50):
    if n > 50:
        raise ValueError("Batch size cannot be greater than 50.")
    try:
        datasets = ','.join([
            # 'aster30m',
            'etopo1',
            # 'eudem25m',
            # 'mapzen',
            'ned10m',
            'srtm30m',
            # 'gebco2020',
            'emod2018',
        ])

        elevations = []
        for i in range(0, len(lats), n):
            batch_lats = lats[i:i + n]
            batch_lons = lons[i:i + n]
            locations = '|'.join([f'{lat},{lon}' for lat, lon in zip(batch_lats, batch_lons)])
            #time.sleep(1.0) # free api
            res = requests.get(f'https://api.opentopodata.org/v1/{datasets}?locations={locations}')
            if res.status_code != 200:
                raise Exception(res.json())
            data = json.loads(res.text)

            batch_elevations = [dataset_response['elevation'] * 3.28084 if dataset_response['elevation'] is not None else None for dataset_response in data['results']]
            elevations.extend(batch_elevations)

        return elevations
    except Exception as e:
        print(e)
        return None

def get_geocoding(name, address):
    if address is None:
        city = None
        state = None
        zip_code = None
    else:
        city = address.city
        state = address.state
        zip_code = address.zipCode
    items = [name, city, state, zip_code]
    items = list(filter(None, items))
    geocoding_address = ', '.join(items)

    geocoding_id = None

    geocoding = {
        'requestedAddress': geocoding_address,
        'codedAddress': None,
        'latitude': None,
        'longitude': None,
        'provider': None,
        'h3Index': None,
        'name': name,
        'city': city,
        'state': state,
        'zipCode': zip_code,
        'elevation': None,
        'lastUpdated': None
    }

    geolocators = {
        "ArcGIS": ArcGIS(), 
        "OSM":Nominatim(user_agent="venue_locator")
    }
    for provider, geolocator in geolocators.items():
        try:
            location = geolocator.geocode(geocoding_address)
            if location:
                geocoding_id = name_filter(location.address)
                geocoding['provider'] = provider
                geocoding['latitude'] = location.latitude
                geocoding['longitude'] = location.longitude
                geocoding['codedAddress'] = location.address
                geocoding['h3Index'] = h3.geo_to_h3(location.latitude, location.longitude, 15)
                geocoding['elevation'] = get_elevations([location.latitude], [location.longitude])[0]
                geocoding['lastUpdated'] = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                return {geocoding_id: geocoding}
        except:
            continue
    return {geocoding_id: geocoding}

def clean_string(s):
    if isinstance(s, str):
        return re.sub("[^A-Za-z0-9 ]+", '', s)
    else:
        return s


def re_braces(s):
    if isinstance(s, str):
        return re.sub("[\(\[].*?[\)\]]", "", s)
    else:
        return s


def name_filter(s):
    if isinstance(s, str):
        # Adds space to words that
        s = re.sub(r'(?<=[a-z])(?=[A-Z])', ' ', s)
        if 'Mary' not in s and ' State' not in s:
            s = s.replace(' St', ' State')
        if 'University' not in s:
            s = s.replace('Univ', 'University')
        if 'zz' in s or 'zzz' in s or 'zzzz' in s:
            s = s.replace('zzzz', '').replace('zzz', '').replace('zz', '')
        s = clean_string(s)
        s = re_braces(s)
        s = str(s)
        s = s.replace(' ', '').lower()
        return s
    else:
        return s

def get_new_venue_coding(sport_str, league_str, venue_id):
    venue = None
    try:
        venue_api = ESPNVenueAPI(sport_str, league_str, venue_id)
        venue = venue_api.get_venue()
        geocoding = get_geocoding(venue.fullName, venue.address)

        if geocoding.keys() == {None}:
            print(f"Geocoding not found for: {sport_str} {league_str} {venue_id}")
        obj = json.loads(venue.json())
        obj.pop('id')
        obj.pop('address')
        new_venue_obj = {
            venue_id : obj
        }

        new_venue_obj[venue_id]['geocodingId'] = list(geocoding.keys())[0]
        new_venue_obj[venue_id]['lastUpdated'] = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

        return new_venue_obj, geocoding
    except Exception as e:
        print(venue)
        raise e

# %%
root_path = '../../data'
geocoding_path = root_path+'/' + 'geocoding.json'
geocoding_addresses = get_json_file(geocoding_path)

sport_league_pairs = list(ESPNSportLeagueTypes)
sport_league_pairs = [
    ESPNSportLeagueTypes.FOOTBALL_NFL,
    ESPNSportLeagueTypes.FOOTBALL_COLLEGE_FOOTBALL,
    ESPNSportLeagueTypes.BASKETBALL_MENS_COLLEGE_BASKETBALL,
    ESPNSportLeagueTypes.BASKETBALL_NBA,
    ESPNSportLeagueTypes.BASKETBALL_WNBA,
    ESPNSportLeagueTypes.BASKETBALL_WOMENS_COLLEGE_BASKETBALL,
]
for sport_league in sport_league_pairs:
    sport_str, league_str = sport_league.value.split('/')
    path = f'{root_path}/{sport_str}/{league_str}/'
    if not os.path.exists(path):
        os.makedirs(path, exist_ok=True)
    venue_path = path + 'venues.json'
    
    # For each LeagueAPI get the venue IDs
    league_api = ESPNLeagueAPI(sport_str, league_str)
    venue_ids = list(map(str,league_api.get_venues()))

    # Try to get the saved sport league venue file if it exists.
    sport_league_venues = get_json_file(venue_path)

    # Handle upsert logic for new or stale venue IDs
    existing_venue_ids = list(sport_league_venues.keys())
    new_venue_ids = list(set(venue_ids) - set(existing_venue_ids))
    new_venue_ids = sorted(new_venue_ids)

    # Skip if no new venues
    if len(new_venue_ids) == 0:
        print(f"No new venues for: {league_str} {sport_str} ")
        continue

    print(f"Getting {len(new_venue_ids)} new venues for: {league_str} {sport_str}")
    new_venues = {}
    new_geocodings = {}
    for venue_id in new_venue_ids:
        new_venue_obj, geocoding = get_new_venue_coding(sport_str, league_str, venue_id)
        new_venues.update(new_venue_obj)
        new_geocodings.update(geocoding)

    print(f"Saving new venues for: {league_str} {sport_str} ...")
    put_json_file(venue_path, {**sport_league_venues, **new_venues})

    # Update geocoding addresses master list
    geocoding_addresses = {**geocoding_addresses, **new_geocodings}
    print(f"Saving new geocodings for: {league_str} {sport_str} ...")
    put_json_file(geocoding_path, geocoding_addresses)
    print("\n")
# Out:
# No new venues for: nfl football
# No new venues for: college-football football
# No new venues for: mens-college-basketball basketball
# Getting 636 new venues for: nba basketball
# Saving new venues for: nba basketball ...
# Saving new geocodings for: nba basketball ...
#
#
# Getting 212 new venues for: wnba basketball
# Saving new venues for: wnba basketball ...
# Saving new geocodings for: wnba basketball ...
#
#
# Getting 916 new venues for: womens-college-basketball basketball
# Saving new venues for: womens-college-basketball basketball ...
# Saving new geocodings for: womens-college-basketball basketball ...

# %%
import json
import os

from espn_api_orm.league.api import ESPNLeagueAPI
from espn_api_orm.season.api import ESPNSeasonAPI
from espn_api_orm.team.api import ESPNTeamAPI
from espn_api_orm.consts import ESPNSportLeagueTypes
import re
import json

## Keys
# franchiseId - team.id 
# teamId - team.slug
# teamSeasonId - season-team.id

def clean_string(s):
    if isinstance(s, str):
        return re.sub("[^A-Za-z0-9 ]+", '', s)
    else:
        return s


def re_braces(s):
    if isinstance(s, str):
        return re.sub("[\(\[].*?[\)\]]", "", s)
    else:
        return s


def name_filter(s):
    if isinstance(s, str):
        # Adds space to words that
        s = re.sub(r'(?<=[a-z])(?=[A-Z])', ' ', s)
        if 'Mary' not in s and ' State' not in s:
            s = s.replace(' St', ' State')
        if 'University' not in s:
            s = s.replace('Univ', 'University')
        if 'zz' in s or 'zzz' in s or 'zzzz' in s:
            s = s.replace('zzzz', '').replace('zzz', '').replace('zz', '')
        s = clean_string(s)
        s = re_braces(s)
        s = str(s)
        s = s.replace(' ', '').lower()
        return s
    else:
        return s

def get_json_file(path):
    try:
        with open(path, 'r') as file:
            return json.load(file)
    except Exception as e:
        return {}

# Function to save sport league file
def put_json_file(path, data):
    with open(path, 'w') as file:
        json.dump(data, file, indent=4)
root_path = '../../data'

sport_league_pairs = list(ESPNSportLeagueTypes)
sport_league_pairs = [
    ESPNSportLeagueTypes.FOOTBALL_NFL,
    ESPNSportLeagueTypes.FOOTBALL_COLLEGE_FOOTBALL
]

def make_team(team):
    id = team.slug
    print('Making Team: ',id )
    return {
        'id': id,
        'franchiseId': team.id,
        'guid': team.guid,
        'uid': team.uid,
        'alternateIds': team.alternateIds,
        'location': team.location.strip() if team.location else None,
        'name': team.name.strip() if team.name else None,
        'nickname': team.nickname.strip() if team.nickname else None,
        'abbreviation': team.abbreviation.strip() if team.abbreviation else None,
        'displayName': team.displayName.strip() if team.displayName else None,
        'shortDisplayName': team.shortDisplayName.strip() if team.shortDisplayName else None,
        'color': team.color.strip() if team.color else None,
        'alternateColor': team.alternateColor.strip() if team.alternateColor else None,
        'isActive': team.isActive,
        'isAllStar': team.isAllStar,
        'college': team.college.strip() if team.college else None,
        'venueId': team.venue.id if team.venue else None,
    }

def make_season_team(season_team, season):
    return {
        'id': f"{season}-{season_team.id}",
        'teamId': season_team.slug,
        'franchiseId': season_team.id,
        'season': season
    }

for sport_league in sport_league_pairs:
    sport_str, league_str = sport_league.value.split('/')
    path = f'{root_path}/{sport_str}/{league_str}/'
    if not os.path.exists(path):
        os.makedirs(path, exist_ok=True)

    # Get existing teams for sport league
    teams_path = path + 'teams.json'
    existing_teams = get_json_file(teams_path)
    # convert dictionary to list with id key added to team payload
    existing_teams = [{**existing_teams[id], 'id': id} for id in existing_teams]

    league_api = ESPNLeagueAPI(sport_str, league_str)

    # Get new teams
    existing_franchise_ids = [i['franchiseId'] for i in existing_teams] if existing_teams != {} else []
    franchise_ids = league_api.get_franchises()
    new_franchise_ids = list(set(franchise_ids) - set(existing_franchise_ids))
    new_franchise_ids = sorted(new_franchise_ids)

    print(f"Getting {len(new_franchise_ids)} new franchises for: {league_str} {sport_str}")

    teams = league_api.get_teams(new_franchise_ids)
    teams = [make_team(i) for i in teams]
    if existing_teams != {}:
        for existing_team in existing_teams:
            if existing_team['franchiseId'] not in new_franchise_ids:
                teams.append(existing_team)
    # Create an id to franchiseId dict mapper to define all teams in league
    team_dict = {i['id']:i['franchiseId'] for i in teams}

    # Get latest season
    seasons = sorted([i for i in league_api.get_seasons() if i > 2001])
    for season in sorted(seasons, reverse=True):
        team_season_path = f"{path}{season}/teams.json"
        season_teams = get_json_file(team_season_path)
        if season_teams != {}:
            seasons = list(range(season, seasons[-1]+1))
            break

    print(f"Running for seasons: {seasons[0]}-{seasons[-1]}")
    # get teams for seasons
    for season in seasons:
        print("*"*20)
        print(f"Season: {season}")
        print("*"*20)
        print()
        # define the season api
        season_api = ESPNSeasonAPI(sport_str, league_str, season)
        if not os.path.exists(path+str(season)):
            os.makedirs(path+str(season), exist_ok=True)

        # Get existing teams for season for the sport league
        team_season_path = f"{path}{season}/teams.json"
        existing_season_teams = get_json_file(team_season_path)
        new_season_teams = []
        existing_season_team_ids= [i['teamId'] for i in existing_season_teams] if existing_season_teams != {} else []

        # Get new teams for season
        season_team_ids = season_api.get_team_season_ids()
        new_season_team_ids = list(set(season_team_ids) - set(existing_season_team_ids))
        new_season_team_ids = sorted(season_team_ids)

        print(f"Getting {len(new_season_team_ids)} new season teams for: {league_str} {sport_str} {season}")

        for team_id in new_season_team_ids:
            # define team api
            team_api = ESPNTeamAPI(sport_str, league_str, season, team_id)
            team_obj = team_api.get_team()
            new_season_team = make_season_team(team_obj, season)
            new_season_teams.append(new_season_team)

            # If team doesn't exist, add it to the teams list and add it to the team dict
            if team_obj.slug not in team_dict:
                teams.append(make_team(team_obj))
                team_dict[team_obj.slug] = team_id

        # Write new season teams to file
        put_json_file(team_season_path, new_season_teams)

    # Write teams to file
    dict_teams = {i.pop('id'):i for i in teams}
    put_json_file(teams_path, dict_teams)
# Out:
# Getting 0 new franchises for: nfl football
# Running for seasons: 2024-2024
# ********************
# Season: 2024
# ********************
#
# Getting 0 new franchises for: college-football football
# Running for seasons: 2006-2024
# ********************
# Season: 2006
# ********************
#
# ********************
# Season: 2007
# ********************
#
# Making Team:  amherst-college-lord-jeffs
# Making Team:  bridgewater-state-bears
# Making Team:  colby-white-mules
# Making Team:  curry-colonels
# Making Team:  elmhurst-blue-jays
# Making Team:  tufts-jumbos
# Making Team:  st-olaf-college-oles
# Making Team:  washington-mo-bears
# Making Team:  hamline-fighting-pipers
# Making Team:  southeastern-university-fire
# Making Team:  lawrence-vikings
# Making Team:  macmurray-college-highlanders
# Making Team:  muskingum-muskies
# Making Team:  wesleyan-cardinals
# Making Team:  kenyon-lords
# Making Team:  utica-college-pioneers
# Making Team:  wheaton-college-ill-thunder
# Making Team:  wilkes-colonels
# Making Team:  maranatha-baptist-college-crusaders
# Making Team:  capital-crusaders
# Making Team:  westminster-blue-jays
# Making Team:  martin-luther-college-knights
# Making Team:  crown-college-storm
# Making Team:  austin-college-kangaroos
# Making Team:  bridgewater-va-eagles
# Making Team:  carleton-knights
# Making Team:  coe-kohawks
# Making Team:  concordia-il-cougars
# Making Team:  dickinson-red-devils
# Making Team:  hiram-terriers
# Making Team:  louisiana-college-wildcats
# Making Team:  marian-knights
# Making Team:  rhodes-lynx
# Making Team:  thomas-more-saints
# Making Team:  trinity-il-trojans
# Making Team:  wartburg-knights
# Making Team:  uw-river-falls-falcons
# Making Team:  wilmington-oh-quakers
# Making Team:  worcester-polytechnic-engineers
# Making Team:  st-thomas-mn-tommies
# Making Team:  huntingdon-hawks
# Making Team:  central-dutch
# Making Team:  morrisville-state-mustangs
# ********************
# Season: 2008
# ********************
#
# Making Team:  st-scholastica-college-of-st-scholastica
# Making Team:  lake-erie-college-storm
# Making Team:  baker-university-wildcats
# Making Team:  dakota-state-trojans
# Making Team:  malone-pioneers
# Making Team:  seton-hill-college-griffins
# Making Team:  campbell-camels
# Making Team:  st-vincent-bearcats
# ********************
# Season: 2009
# ********************
#
# Making Team:  castleton-state-college-spartans
# Making Team:  bethany-ks-swedes
# Making Team:  midland-university-warriors
# Making Team:  south-all-stars
# Making Team:  north-all-stars
# Making Team:  east-all-stars
# Making Team:  west-all-stars
# ********************
# Season: 2010
# ********************
#
# Making Team:  monterrey-tech-rams
# ********************
# Season: 2011
# ********************
#
# Making Team:  bacone
# Making Team:  ut-san-antonio-roadrunners
# Making Team:  american
# Making Team:  national
# Making Team:  north-florida-stars
# Making Team:  south-florida-stars
# ********************
# Season: 2012
# ********************
#
# Making Team:  culver-stockton-college-wildcats
# Making Team:  graceland-university-yellowjackets
# Making Team:  kansas-wesleyan-university-coyotes
# Making Team:  notre-dame-college-blue-falcons
# Making Team:  presentation-college-saints
# Making Team:  robert-morris-il-eagles
# Making Team:  sterling-college-warriors
# Making Team:  des-moines-vikings
# Making Team:  langston-university-lions
# Making Team:  virginia-university-of-lynchburg-dragons
# Making Team:  wright-state-university-raiders
# Making Team:  evangel-university-crusaders
# Making Team:  william-jewell-college-cardinals
# Making Team:  point-university-point
# ********************
# Season: 2013
# ********************
#
# Making Team:  florida-tech-panthers
# Making Team:  alderson-broaddus-battlers
# Making Team:  houston-baptist-huskies
# Making Team:  lynchburg-hornets
# ********************
# Season: 2014
# ********************
#
# Making Team:  george-fox-university-bruins
# Making Team:  bluefield-college-rams
# Making Team:  dakota-wesleyan-tigers
# Making Team:  paine-lions
# Making Team:  lindsey-wilson-blue-raiders
# Making Team:  lakeland-college-lakeland
# Making Team:  benedictine-college-bndctne-col
# ********************
# Season: 2015
# ********************
#
# Making Team:  college-of-faith-warriors
# ********************
# Season: 2016
# ********************
#
# Making Team:  east-tennessee-st-buccaneers
# Making Team:  prairie-view-panthers
# Making Team:  nebraska-wesleyan-university-neb-wesleyan
# Making Team:  davenport-panthers
# ********************
# Season: 2017
# ********************
#
# Making Team:  rowan-professors
# Making Team:  ripon-redhawks
# Making Team:  lakeland-university-lakeland
# ********************
# Season: 2018
# ********************
#
# Making Team:  colby-college-mules
# Making Team:  springfield-college-pride
# Making Team:  st-olaf-college-lions
# Making Team:  washington-missouri-bears
# Making Team:  millersville-university-marauders
# Making Team:  union-college-ny-dutchmen
# Making Team:  wesleyan-university-cardinals
# Making Team:  st-john-fisher-college-cardinals
# Making Team:  wheaton-college-illinois-thunder
# Making Team:  capital-university-crusaders
# Making Team:  westminster-college-mo-blue-jays
# Making Team:  stevenson-university-mustangs
# Making Team:  crown-storm
# Making Team:  carthage-college-redmen
# Making Team:  lane-college-dragons
# Making Team:  randolph-macon-college-yellow-jackets
# Making Team:  rockford-university-regents
# Making Team:  rensselaer-polytechnic-institute-engineers
# Making Team:  st-vincent-college-bearcats
# Making Team:  ursinus-college-bears
# Making Team:  washington-lee-university-generals
# Making Team:  western-state-colorado-mountaineers
# Making Team:  williams-college-ephs
# Making Team:  wittenberg-university-tigers
# Making Team:  college-of-wooster-fighting-scots
# Making Team:  salve-regina-university-seahawks
# Making Team:  college-at-brockport-golden-eagles
# Making Team:  minnesota-st-moorhead-dragons
# Making Team:  rowan-university-owls
# Making Team:  shenandoah-university-hornets
# Making Team:  simon-fraser-clan
# Making Team:  st-norbert-college-green-knights
# Making Team:  sul-ross-state-university-lobos
# Making Team:  waynesburg-university-yellow-jackets
# Making Team:  westminster-college-pa-titans
# Making Team:  north-carolina-pembroke-braves
# Making Team:  northwood-university-timberwolves
# Making Team:  ripon-college-redhawks
# Making Team:  university-of-st-thomas-mn-tommies
# Making Team:  pomona-pitzer-colleges-sagehens
# Making Team:  plymouth-state-college-panthers
# Making Team:  trinity-college-ct-bantams
# Making Team:  dixie-state-college-trailblazers
# Making Team:  lakeland-college-muskies
# Making Team:  nebraska-wesleyan-university-prairie-wolves
# Making Team:  benedictine-college-ravens
# Making Team:  alvernia-university-golden-wolves
# ********************
# Season: 2019
# ********************
#
# Making Team:  san-jose-st-spartans
# Making Team:  stonehill-college-skyhawks
# Making Team:  bluefield-college-ramblin-rams
# Making Team:  crown-polars
# Making Team:  notre-dame-college-falcons
# Making Team:  british-columbia-thunderbirds
# Making Team:  carthage-college-red-men
# Making Team:  maryville-tn-scots
# Making Team:  trinity-il-trinity-il
# Making Team:  wilmington-college-fightin-quakers
# Making Team:  alma-college-alma
# Making Team:  oklahoma-panhandle-state-aggies
# Making Team:  lindsey-wilson-lindsey
# Making Team:  dixie-state-university-trailblazers
# Making Team:  kai-hulakai
# Making Team:  aina-hulaaina
# Making Team:  wheeling-jesuit-cardinals
# ********************
# Season: 2020
# ********************
#
# Making Team:  univ-of-northwestern-st-paul-eagles
# Making Team:  carthage-college-firebirds
# Making Team:  concordia-minnesota-cobbers
# Making Team:  maryville-college-fighting-scots
# Making Team:  rpi-engineers
# Making Team:  tarleton-texans
# Making Team:  dixie-state-trailblazers
# Making Team:  wheeling-university-cardinals
# Making Team:  la-plume-giants
# ********************
# Season: 2021
# ********************
#
# Making Team:  union-garnet-chargers
# Making Team:  maryville-college-scots
# Making Team:  lindsey-wilson-college-blue-raiders
# Making Team:  st-thomas---minnesota-tommies
# Making Team:  lawrence-tech-blue-devils
# Making Team:  university-of-texas-of-the-permian-basin-falcons
# Making Team:  keystone-giants
# Making Team:  lincoln-university-ca-oaklanders
# Making Team:  bluefield-bluefields
# Making Team:  montanastn-montanastn
# Making Team:  team-gaither
# Making Team:  team-robinson
# ********************
# Season: 2022
# ********************
#
# Making Team:  william-paterson-bears
# Making Team:  bluefield-big-blues
# Making Team:  hilbert-college-hilbert
# Making Team:  keiser-university-seahawks
# ********************
# Season: 2023
# ********************
#
# Making Team:  northeastern-state-river-hawks
# Making Team:  union-ny-dutchmen
# Making Team:  mcmurry-indians
# Making Team:  maine-maritime-null
# Making Team:  becker-college-null
# Making Team:  cumberland-ky-patriots
# Making Team:  wesley-college-null
# ********************
# Season: 2024
# ********************
#
# Making Team:  centenary-gentlemen
# Making Team:  roosevelt-lakers
# Making Team:  anderson-sc-trojans
# Making Team:  calvin-university-knights

# %%
league_str = 'nfl'

path = f'{root_path}/{sport_str}/{league_str}/'
teams_path = path + 'teams.json'
venue_path = path + 'venues.json'
geocoding_path = root_path+'/' + 'geocoding.json'


teams = get_json_file(teams_path)
geocoding_addresses = get_json_file(geocoding_path)
sport_league_venues = get_json_file(venue_path)

season_teams = get_json_file(path + str(season) + '/teams.json')

# %%
full_teams = []
for season_team in season_teams:
    season_team['team'] = teams.get(str(season_team['teamId']), None)
    season_team['venue'] = sport_league_venues.get(str(season_team['team']['venueId']), None)
    season_team['geocoding'] = None
    if season_team['venue'] is not None:
        season_team['geocoding'] = geocoding_addresses.get(season_team['venue']['geocodingId'], None)
    full_teams.append(season_team)

full_teams
# Out:
# [{'id': '2024-1',
#   'teamId': 'atlanta-falcons',
#   'franchiseId': 1,
#   'season': 2024,
#   'team': {'franchiseId': 1,
#    'guid': '49fd392a-86fe-4df3-1b77-9bbfa18b2ad5',
#    'uid': 's:20~l:28~t:1',
#    'alternateIds': {'sdr': '8802'},
#    'location': 'Atlanta',
#    'name': 'Falcons',
#    'nickname': 'Falcons',
#    'abbreviation': 'ATL',
#    'displayName': 'Atlanta Falcons',
#    'shortDisplayName': 'Falcons',
#    'color': '000000',
#    'alternateColor': '000000',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3495},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3495?lang=en&region=us',
#    'fullName': 'Georgia Dome',
#    'capacity': None,
#    'grass': False,
#    'indoor': True,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3495.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3495.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'georgiadome',
#    'lastUpdated': '2024-06-17 14:17:22'},
#   'geocoding': {'requestedAddress': 'Georgia Dome, Atlanta, GA, 39901',
#    'codedAddress': 'Georgia Dome',
#    'latitude': 33.7580404,
#    'longitude': -84.3996348,
#    'provider': 'ArcGIS',
#    'h3Index': '8f44c1a8ccad694',
#    'name': 'Georgia Dome',
#    'city': 'Atlanta',
#    'state': 'GA',
#    'zipCode': '39901',
#    'elevation': 1017.0604,
#    'lastUpdated': '2024-06-17 18:02:52'}},
#  {'id': '2024-2',
#   'teamId': 'buffalo-bills',
#   'franchiseId': 2,
#   'season': 2024,
#   'team': {'franchiseId': 2,
#    'guid': '232afaf2-01ac-fcc2-8bd6-66550df1703a',
#    'uid': 's:20~l:28~t:2',
#    'alternateIds': {'sdr': '8804'},
#    'location': 'Buffalo',
#    'name': 'Bills',
#    'nickname': 'Bills',
#    'abbreviation': 'BUF',
#    'displayName': 'Buffalo Bills',
#    'shortDisplayName': 'Bills',
#    'color': '04407F',
#    'alternateColor': 'd50a0a',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3883},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3883?lang=en&region=us',
#    'fullName': 'Highmark Stadium',
#    'capacity': None,
#    'grass': False,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3883.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3883.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'highmarkstateadium',
#    'lastUpdated': '2024-06-17 14:22:22'},
#   'geocoding': {'requestedAddress': 'Highmark Stadium, Orchard Park, NY, 14127',
#    'codedAddress': 'Highmark Stadium',
#    'latitude': 42.7737501,
#    'longitude': -78.7869961,
#    'provider': 'ArcGIS',
#    'h3Index': '8f2aa6cd65ad2a8',
#    'name': 'Highmark Stadium',
#    'city': 'Orchard Park',
#    'state': 'NY',
#    'zipCode': '14127',
#    'elevation': 734.90816,
#    'lastUpdated': '2024-06-17 14:34:07'}},
#  {'id': '2024-3',
#   'teamId': 'chicago-bears',
#   'franchiseId': 3,
#   'season': 2024,
#   'team': {'franchiseId': 3,
#    'guid': '19d73366-b5a5-cca2-a176-a2c024ce0bb3',
#    'uid': 's:20~l:28~t:3',
#    'alternateIds': {'sdr': '8806'},
#    'location': 'Chicago',
#    'name': 'Bears',
#    'nickname': 'Bears',
#    'abbreviation': 'CHI',
#    'displayName': 'Chicago Bears',
#    'shortDisplayName': 'Bears',
#    'color': '152644',
#    'alternateColor': 'e64100',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3933},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3933?lang=en&region=us',
#    'fullName': 'Soldier Field',
#    'capacity': None,
#    'grass': True,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3933.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3933.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'soldierfield',
#    'lastUpdated': '2024-06-17 14:23:17'},
#   'geocoding': {'requestedAddress': 'Soldier Field, Chicago, IL, 60605',
#    'codedAddress': 'Soldier Field',
#    'latitude': 41.8639164,
#    'longitude': -87.6167044,
#    'provider': 'ArcGIS',
#    'h3Index': '8f2664c1bc42683',
#    'name': 'Soldier Field',
#    'city': 'Chicago',
#    'state': 'IL',
#    'zipCode': '60605',
#    'elevation': 613.51708,
#    'lastUpdated': '2024-06-17 14:34:55'}},
#  {'id': '2024-4',
#   'teamId': 'cincinnati-bengals',
#   'franchiseId': 4,
#   'season': 2024,
#   'team': {'franchiseId': 4,
#    'guid': '75b8623b-8926-b411-0476-3d3602b78523',
#    'uid': 's:20~l:28~t:4',
#    'alternateIds': {'sdr': '8807'},
#    'location': 'Cincinnati',
#    'name': 'Bengals',
#    'nickname': 'Bengals',
#    'abbreviation': 'CIN',
#    'displayName': 'Cincinnati Bengals',
#    'shortDisplayName': 'Bengals',
#    'color': 'FF2700',
#    'alternateColor': '000000',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3874},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3874?lang=en&region=us',
#    'fullName': 'Paycor Stadium',
#    'capacity': None,
#    'grass': False,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3874.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3874.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'paycorstateadium',
#    'lastUpdated': '2024-06-17 14:22:12'},
#   'geocoding': {'requestedAddress': 'Paycor Stadium, Cincinnati, OH, 45202',
#    'codedAddress': 'Paycor Stadium',
#    'latitude': 39.0945965,
#    'longitude': -84.5172694,
#    'provider': 'ArcGIS',
#    'h3Index': '8f2a930f0250756',
#    'name': 'Paycor Stadium',
#    'city': 'Cincinnati',
#    'state': 'OH',
#    'zipCode': '45202',
#    'elevation': 531.49608,
#    'lastUpdated': '2024-06-17 14:33:58'}},
#  {'id': '2024-5',
#   'teamId': 'cleveland-browns',
#   'franchiseId': 5,
#   'season': 2024,
#   'team': {'franchiseId': 5,
#    'guid': '539babc5-e5fb-753b-8ae1-c15032a91ef4',
#    'uid': 's:20~l:28~t:5',
#    'alternateIds': {'sdr': '8808'},
#    'location': 'Cleveland',
#    'name': 'Browns',
#    'nickname': 'Browns',
#    'abbreviation': 'CLE',
#    'displayName': 'Cleveland Browns',
#    'shortDisplayName': 'Browns',
#    'color': '4C230E',
#    'alternateColor': 'ff3c00',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3679},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3679?lang=en&region=us',
#    'fullName': 'Cleveland Browns Stadium',
#    'capacity': None,
#    'grass': True,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3679.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3679.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'clevelandbrownsstateadium',
#    'lastUpdated': '2024-06-17 14:18:50'},
#   'geocoding': {'requestedAddress': 'Cleveland Browns Stadium, Cleveland, OH, 44114',
#    'codedAddress': "Cleveland Brown's Stadium",
#    'latitude': 41.5048656,
#    'longitude': -81.7004336,
#    'provider': 'ArcGIS',
#    'h3Index': '8f2ab381b616cd9',
#    'name': 'Cleveland Browns Stadium',
#    'city': 'Cleveland',
#    'state': 'OH',
#    'zipCode': '44114',
#    'elevation': 587.27036,
#    'lastUpdated': '2024-06-17 14:30:41'}},
#  {'id': '2024-6',
#   'teamId': 'dallas-cowboys',
#   'franchiseId': 6,
#   'season': 2024,
#   'team': {'franchiseId': 6,
#    'guid': 'b0fc8fb7-9dbe-e574-9008-6f0ee7c6b234',
#    'uid': 's:20~l:28~t:6',
#    'alternateIds': {'sdr': '8809'},
#    'location': 'Dallas',
#    'name': 'Cowboys',
#    'nickname': 'Cowboys',
#    'abbreviation': 'DAL',
#    'displayName': 'Dallas Cowboys',
#    'shortDisplayName': 'Cowboys',
#    'color': '002E4D',
#    'alternateColor': 'b0b7bc',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3687},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3687?lang=en&region=us',
#    'fullName': 'AT&T Stadium',
#    'capacity': None,
#    'grass': False,
#    'indoor': True,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3687.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3687.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'attstateadium',
#    'lastUpdated': '2024-06-17 14:18:57'},
#   'geocoding': {'requestedAddress': 'AT&T Stadium, Arlington, TX, 76011',
#    'codedAddress': 'AT&T Stadium',
#    'latitude': 32.74694,
#    'longitude': -97.0923976,
#    'provider': 'ArcGIS',
#    'h3Index': '8f26cbd74ca1148',
#    'name': 'AT&T Stadium',
#    'city': 'Arlington',
#    'state': 'TX',
#    'zipCode': '76011',
#    'elevation': 587.27036,
#    'lastUpdated': '2024-06-17 18:03:07'}},
#  {'id': '2024-7',
#   'teamId': 'denver-broncos',
#   'franchiseId': 7,
#   'season': 2024,
#   'team': {'franchiseId': 7,
#    'guid': '51042145-e3c1-0694-ae0d-f720342ff8fc',
#    'uid': 's:20~l:28~t:7',
#    'alternateIds': {'sdr': '8810'},
#    'location': 'Denver',
#    'name': 'Broncos',
#    'nickname': 'Broncos',
#    'abbreviation': 'DEN',
#    'displayName': 'Denver Broncos',
#    'shortDisplayName': 'Broncos',
#    'color': '002E4D',
#    'alternateColor': 'fc4c02',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3937},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3937?lang=en&region=us',
#    'fullName': 'Empower Field at Mile High',
#    'capacity': None,
#    'grass': True,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3937.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3937.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': '80204denvercolorado',
#    'lastUpdated': '2024-06-17 14:23:21'},
#   'geocoding': {'requestedAddress': 'Empower Field at Mile High, Denver, CO, 80204',
#    'codedAddress': '80204, Denver, Colorado',
#    'latitude': 39.733874,
#    'longitude': -105.0211309,
#    'provider': 'ArcGIS',
#    'h3Index': '8f268cdaaccd529',
#    'name': 'Empower Field at Mile High',
#    'city': 'Denver',
#    'state': 'CO',
#    'zipCode': '80204',
#    'elevation': 5242.78232,
#    'lastUpdated': '2024-06-17 14:34:59'}},
#  {'id': '2024-8',
#   'teamId': 'detroit-lions',
#   'franchiseId': 8,
#   'season': 2024,
#   'team': {'franchiseId': 8,
#    'guid': '56caffee-178d-f6f2-a076-b277486b8c32',
#    'uid': 's:20~l:28~t:8',
#    'alternateIds': {'sdr': '8811'},
#    'location': 'Detroit',
#    'name': 'Lions',
#    'nickname': 'Lions',
#    'abbreviation': 'DET',
#    'displayName': 'Detroit Lions',
#    'shortDisplayName': 'Lions',
#    'color': '035C98',
#    'alternateColor': 'bbbbbb',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3727},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3727?lang=en&region=us',
#    'fullName': 'Ford Field',
#    'capacity': None,
#    'grass': False,
#    'indoor': True,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3727.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3727.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'fordfield',
#    'lastUpdated': '2024-06-17 14:19:39'},
#   'geocoding': {'requestedAddress': 'Ford Field, Detroit, MI',
#    'codedAddress': 'Ford Field',
#    'latitude': 42.3387522,
#    'longitude': -83.046304,
#    'provider': 'ArcGIS',
#    'h3Index': '8f2ab2c5c78e4e5',
#    'name': 'Ford Field',
#    'city': 'Detroit',
#    'state': 'MI',
#    'zipCode': None,
#    'elevation': 603.67456,
#    'lastUpdated': '2024-06-17 18:03:10'}},
#  {'id': '2024-9',
#   'teamId': 'green-bay-packers',
#   'franchiseId': 9,
#   'season': 2024,
#   'team': {'franchiseId': 9,
#    'guid': '06cd3bcf-7a86-53d4-28e7-aa049dd36261',
#    'uid': 's:20~l:28~t:9',
#    'alternateIds': {'sdr': '8812'},
#    'location': 'Green Bay',
#    'name': 'Packers',
#    'nickname': 'Packers',
#    'abbreviation': 'GB',
#    'displayName': 'Green Bay Packers',
#    'shortDisplayName': 'Packers',
#    'color': '204E32',
#    'alternateColor': 'ffb612',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3798},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3798?lang=en&region=us',
#    'fullName': 'Lambeau Field',
#    'capacity': None,
#    'grass': True,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3798.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3798.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'lambeaufield',
#    'lastUpdated': '2024-06-17 14:20:55'},
#   'geocoding': {'requestedAddress': 'Lambeau Field, Green Bay, WI, 54304',
#    'codedAddress': 'Lambeau Field',
#    'latitude': 44.5018253,
#    'longitude': -88.0604251,
#    'provider': 'ArcGIS',
#    'h3Index': '8f27434269b350b',
#    'name': 'Lambeau Field',
#    'city': 'Green Bay',
#    'state': 'WI',
#    'zipCode': '54304',
#    'elevation': 636.48296,
#    'lastUpdated': '2024-06-17 14:32:42'}},
#  {'id': '2024-10',
#   'teamId': 'tennessee-titans',
#   'franchiseId': 10,
#   'season': 2024,
#   'team': {'franchiseId': 10,
#    'guid': '0a0aea59-9a5e-01b3-57a3-0151cf4bf393',
#    'uid': 's:20~l:28~t:10',
#    'alternateIds': {'sdr': '8830'},
#    'location': 'Tennessee',
#    'name': 'Titans',
#    'nickname': 'Titans',
#    'abbreviation': 'TEN',
#    'displayName': 'Tennessee Titans',
#    'shortDisplayName': 'Titans',
#    'color': '2F95DD',
#    'alternateColor': '002a5c',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3810},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3810?lang=en&region=us',
#    'fullName': 'Nissan Stadium',
#    'capacity': None,
#    'grass': False,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3810.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3810.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'nissanstateadium',
#    'lastUpdated': '2024-06-17 14:21:08'},
#   'geocoding': {'requestedAddress': 'Nissan Stadium, Nashville, TN, 37213',
#    'codedAddress': 'Nissan Stadium',
#    'latitude': 36.1667149,
#    'longitude': -86.7709786,
#    'provider': 'ArcGIS',
#    'h3Index': '8f264d106b5086b',
#    'name': 'Nissan Stadium',
#    'city': 'Nashville',
#    'state': 'TN',
#    'zipCode': '37213',
#    'elevation': 439.63256,
#    'lastUpdated': '2024-06-17 14:32:56'}},
#  {'id': '2024-11',
#   'teamId': 'indianapolis-colts',
#   'franchiseId': 11,
#   'season': 2024,
#   'team': {'franchiseId': 11,
#    'guid': '582d14eb-da61-e505-cc40-d972a1b60ed1',
#    'uid': 's:20~l:28~t:11',
#    'alternateIds': {'sdr': '8813'},
#    'location': 'Indianapolis',
#    'name': 'Colts',
#    'nickname': 'Colts',
#    'abbreviation': 'IND',
#    'displayName': 'Indianapolis Colts',
#    'shortDisplayName': 'Colts',
#    'color': '00417E',
#    'alternateColor': 'ffffff',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3812},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3812?lang=en&region=us',
#    'fullName': 'Lucas Oil Stadium',
#    'capacity': None,
#    'grass': False,
#    'indoor': True,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3812.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3812.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'lucasoilstateadium',
#    'lastUpdated': '2024-06-17 14:21:10'},
#   'geocoding': {'requestedAddress': 'Lucas Oil Stadium, Indianapolis, IN, 46225',
#    'codedAddress': 'Lucas Oil Stadium',
#    'latitude': 39.7610486,
#    'longitude': -86.1632109,
#    'provider': 'ArcGIS',
#    'h3Index': '8f2661a210c01a5',
#    'name': 'Lucas Oil Stadium',
#    'city': 'Indianapolis',
#    'state': 'IN',
#    'zipCode': '46225',
#    'elevation': 715.22312,
#    'lastUpdated': '2024-06-17 15:38:59'}},
#  {'id': '2024-12',
#   'teamId': 'kansas-city-chiefs',
#   'franchiseId': 12,
#   'season': 2024,
#   'team': {'franchiseId': 12,
#    'guid': 'f68f2343-8ceb-7a02-740d-af6338be21d2',
#    'uid': 's:20~l:28~t:12',
#    'alternateIds': {'sdr': '8815'},
#    'location': 'Kansas City',
#    'name': 'Chiefs',
#    'nickname': 'Chiefs',
#    'abbreviation': 'KC',
#    'displayName': 'Kansas City Chiefs',
#    'shortDisplayName': 'Chiefs',
#    'color': 'BE1415',
#    'alternateColor': 'ffb612',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3622},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3622?lang=en&region=us',
#    'fullName': 'GEHA Field at Arrowhead Stadium',
#    'capacity': None,
#    'grass': True,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3622.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3622.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'arrowheadstateadium',
#    'lastUpdated': '2024-06-17 14:17:51'},
#   'geocoding': {'requestedAddress': 'GEHA Field at Arrowhead Stadium, Kansas City, MO, 64129',
#    'codedAddress': 'Arrowhead Stadium',
#    'latitude': 39.0482103,
#    'longitude': -94.483183,
#    'provider': 'ArcGIS',
#    'h3Index': '8f26560c0533244',
#    'name': 'GEHA Field at Arrowhead Stadium',
#    'city': 'Kansas City',
#    'state': 'MO',
#    'zipCode': '64129',
#    'elevation': 892.38848,
#    'lastUpdated': '2024-06-17 14:29:42'}},
#  {'id': '2024-13',
#   'teamId': 'las-vegas-raiders',
#   'franchiseId': 13,
#   'season': 2024,
#   'team': {'franchiseId': 13,
#    'guid': 'b18540eb-6f2b-534c-e7f9-9bd930518da9',
#    'uid': 's:20~l:28~t:13',
#    'alternateIds': {'sdr': '8822'},
#    'location': 'Las Vegas',
#    'name': 'Raiders',
#    'nickname': 'Raiders',
#    'abbreviation': 'LV',
#    'displayName': 'Las Vegas Raiders',
#    'shortDisplayName': 'Raiders',
#    'color': '000000',
#    'alternateColor': 'a5acaf',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 6501},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/6501?lang=en&region=us',
#    'fullName': 'Allegiant Stadium',
#    'capacity': None,
#    'grass': True,
#    'indoor': True,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/6501.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/6501.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'allegiantstateadium',
#    'lastUpdated': '2024-06-17 14:28:33'},
#   'geocoding': {'requestedAddress': 'Allegiant Stadium, Las Vegas, NV, 89118',
#    'codedAddress': 'Allegiant Stadium',
#    'latitude': 36.090887,
#    'longitude': -115.1832285,
#    'provider': 'ArcGIS',
#    'h3Index': '8f2986b84a18cad',
#    'name': 'Allegiant Stadium',
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'zipCode': '89118',
#    'elevation': 2191.60112,
#    'lastUpdated': '2024-06-17 14:43:55'}},
#  {'id': '2024-14',
#   'teamId': 'los-angeles-rams',
#   'franchiseId': 14,
#   'season': 2024,
#   'team': {'franchiseId': 14,
#    'guid': '2e1473b2-e269-fd7a-1137-c1edacb85986',
#    'uid': 's:20~l:28~t:14',
#    'alternateIds': {'sdr': '8828'},
#    'location': 'Los Angeles',
#    'name': 'Rams',
#    'nickname': 'Rams',
#    'abbreviation': 'LAR',
#    'displayName': 'Los Angeles Rams',
#    'shortDisplayName': 'Rams',
#    'color': '00295B',
#    'alternateColor': 'ffd100',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 477},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/477?lang=en&region=us',
#    'fullName': 'Los Angeles Memorial Coliseum',
#    'capacity': None,
#    'grass': True,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/477.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'losangelesmemorialcoliseum',
#    'lastUpdated': '2024-06-17 11:33:23'},
#   'geocoding': {'requestedAddress': 'Los Angeles Memorial Coliseum, Los Angeles, CA, 90037',
#    'codedAddress': 'Los Angeles Memorial Coliseum',
#    'latitude': 34.0140413,
#    'longitude': -118.2862321,
#    'provider': 'ArcGIS',
#    'h3Index': '8f29a1d64c0b561',
#    'name': 'Los Angeles Memorial Coliseum',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'zipCode': '90037',
#    'elevation': 190.28872,
#    'lastUpdated': '2024-06-17 14:37:19'}},
#  {'id': '2024-15',
#   'teamId': 'miami-dolphins',
#   'franchiseId': 15,
#   'season': 2024,
#   'team': {'franchiseId': 15,
#    'guid': 'af33088b-1e19-d27d-dbc0-354fd7151703',
#    'uid': 's:20~l:28~t:15',
#    'alternateIds': {'sdr': '8816'},
#    'location': 'Miami',
#    'name': 'Dolphins',
#    'nickname': 'Dolphins',
#    'abbreviation': 'MIA',
#    'displayName': 'Miami Dolphins',
#    'shortDisplayName': 'Dolphins',
#    'color': '006B79',
#    'alternateColor': 'fc4c02',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3948},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3948?lang=en&region=us',
#    'fullName': 'Hard Rock Stadium',
#    'capacity': None,
#    'grass': True,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3948.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3948.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'hardrockstateadium',
#    'lastUpdated': '2024-06-17 14:23:32'},
#   'geocoding': {'requestedAddress': 'Hard Rock Stadium, Miami Gardens, FL, 33056',
#    'codedAddress': 'Hard Rock Stadium',
#    'latitude': 25.9564193,
#    'longitude': -80.2383487,
#    'provider': 'ArcGIS',
#    'h3Index': '8f44a1060c7138c',
#    'name': 'Hard Rock Stadium',
#    'city': 'Miami Gardens',
#    'state': 'FL',
#    'zipCode': '33056',
#    'elevation': 26.24672,
#    'lastUpdated': '2024-06-17 14:35:10'}},
#  {'id': '2024-16',
#   'teamId': 'minnesota-vikings',
#   'franchiseId': 16,
#   'season': 2024,
#   'team': {'franchiseId': 16,
#    'guid': '3db556c9-ed76-a7a5-4ccb-a92fc6db4334',
#    'uid': 's:20~l:28~t:16',
#    'alternateIds': {'sdr': '8817'},
#    'location': 'Minnesota',
#    'name': 'Vikings',
#    'nickname': 'Vikings',
#    'abbreviation': 'MIN',
#    'displayName': 'Minnesota Vikings',
#    'shortDisplayName': 'Vikings',
#    'color': '240A67',
#    'alternateColor': 'ffc62f',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 16},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/16?lang=en&region=us',
#    'fullName': 'Mall of America Field',
#    'capacity': None,
#    'grass': False,
#    'indoor': True,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/16.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/16.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': '55415minneapolisminnesota',
#    'lastUpdated': '2024-06-17 11:33:16'},
#   'geocoding': {'requestedAddress': 'Mall of America Field, Minneapolis, MN, 55415',
#    'codedAddress': '55415, Minneapolis, Minnesota',
#    'latitude': 44.976008,
#    'longitude': -93.260872,
#    'provider': 'ArcGIS',
#    'h3Index': '8f275268981cac3',
#    'name': 'Mall of America Field',
#    'city': 'Minneapolis',
#    'state': 'MN',
#    'zipCode': '55415',
#    'elevation': 836.6142,
#    'lastUpdated': '2024-06-17 11:33:16'}},
#  {'id': '2024-17',
#   'teamId': 'new-england-patriots',
#   'franchiseId': 17,
#   'season': 2024,
#   'team': {'franchiseId': 17,
#    'guid': '0078f353-fe3e-67ed-a42c-43cca0568e21',
#    'uid': 's:20~l:28~t:17',
#    'alternateIds': {'sdr': '8818'},
#    'location': 'New England',
#    'name': 'Patriots',
#    'nickname': 'Patriots',
#    'abbreviation': 'NE',
#    'displayName': 'New England Patriots',
#    'shortDisplayName': 'Patriots',
#    'color': '02244A',
#    'alternateColor': 'c60c30',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3738},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3738?lang=en&region=us',
#    'fullName': 'Gillette Stadium',
#    'capacity': None,
#    'grass': False,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3738.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3738.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'gillettestateadium',
#    'lastUpdated': '2024-06-17 14:19:51'},
#   'geocoding': {'requestedAddress': 'Gillette Stadium, Foxborough, MA, 02035',
#    'codedAddress': 'Gillette Stadium',
#    'latitude': 42.0909483,
#    'longitude': -71.2643566,
#    'provider': 'ArcGIS',
#    'h3Index': '8f2a338a18f6a51',
#    'name': 'Gillette Stadium',
#    'city': 'Foxborough',
#    'state': 'MA',
#    'zipCode': '02035',
#    'elevation': 291.99476,
#    'lastUpdated': '2024-06-17 14:31:41'}},
#  {'id': '2024-18',
#   'teamId': 'new-orleans-saints',
#   'franchiseId': 18,
#   'season': 2024,
#   'team': {'franchiseId': 18,
#    'guid': '97d2f6c9-2f22-459c-306a-046941ccab2a',
#    'uid': 's:20~l:28~t:18',
#    'alternateIds': {'sdr': '8819'},
#    'location': 'New Orleans',
#    'name': 'Saints',
#    'nickname': 'Saints',
#    'abbreviation': 'NO',
#    'displayName': 'New Orleans Saints',
#    'shortDisplayName': 'Saints',
#    'color': '020202',
#    'alternateColor': '000000',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3493},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3493?lang=en&region=us',
#    'fullName': 'Caesars Superdome',
#    'capacity': None,
#    'grass': False,
#    'indoor': True,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3493.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3493.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': '70112neworleanslouisiana',
#    'lastUpdated': '2024-06-17 14:17:19'},
#   'geocoding': {'requestedAddress': 'Caesars Superdome, New Orleans, LA, 70112',
#    'codedAddress': '70112, New Orleans, Louisiana',
#    'latitude': 29.9537312,
#    'longitude': -90.075884,
#    'provider': 'ArcGIS',
#    'h3Index': '8f44464256a895c',
#    'name': 'Caesars Superdome',
#    'city': 'New Orleans',
#    'state': 'LA',
#    'zipCode': '70112',
#    'elevation': 26.24672,
#    'lastUpdated': '2024-06-17 15:38:40'}},
#  {'id': '2024-19',
#   'teamId': 'new-york-giants',
#   'franchiseId': 19,
#   'season': 2024,
#   'team': {'franchiseId': 19,
#    'guid': '378600ea-2397-8364-8399-b7c1606a49a7',
#    'uid': 's:20~l:28~t:19',
#    'alternateIds': {'sdr': '8820'},
#    'location': 'New York',
#    'name': 'Giants',
#    'nickname': 'Giants',
#    'abbreviation': 'NYG',
#    'displayName': 'New York Giants',
#    'shortDisplayName': 'Giants',
#    'color': '052570',
#    'alternateColor': 'c9243f',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3839},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3839?lang=en&region=us',
#    'fullName': 'MetLife Stadium',
#    'capacity': None,
#    'grass': False,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3839.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3839.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'metlifestateadium',
#    'lastUpdated': '2024-06-17 14:21:38'},
#   'geocoding': {'requestedAddress': 'MetLife Stadium, East Rutherford, NJ, 07073',
#    'codedAddress': 'MetLife Stadium',
#    'latitude': 40.813756,
#    'longitude': -74.0730639,
#    'provider': 'ArcGIS',
#    'h3Index': '8f2a1009ab91c5c',
#    'name': 'MetLife Stadium',
#    'city': 'East Rutherford',
#    'state': 'NJ',
#    'zipCode': '07073',
#    'elevation': 6.56168,
#    'lastUpdated': '2024-06-17 14:33:26'}},
#  {'id': '2024-20',
#   'teamId': 'new-york-jets',
#   'franchiseId': 20,
#   'season': 2024,
#   'team': {'franchiseId': 20,
#    'guid': '732d3caf-b350-1e34-48c6-b7cebb4a0d88',
#    'uid': 's:20~l:28~t:20',
#    'alternateIds': {'sdr': '8821'},
#    'location': 'New York',
#    'name': 'Jets',
#    'nickname': 'Jets',
#    'abbreviation': 'NYJ',
#    'displayName': 'New York Jets',
#    'shortDisplayName': 'Jets',
#    'color': '174032',
#    'alternateColor': 'ffffff',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3839},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3839?lang=en&region=us',
#    'fullName': 'MetLife Stadium',
#    'capacity': None,
#    'grass': False,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3839.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3839.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'metlifestateadium',
#    'lastUpdated': '2024-06-17 14:21:38'},
#   'geocoding': {'requestedAddress': 'MetLife Stadium, East Rutherford, NJ, 07073',
#    'codedAddress': 'MetLife Stadium',
#    'latitude': 40.813756,
#    'longitude': -74.0730639,
#    'provider': 'ArcGIS',
#    'h3Index': '8f2a1009ab91c5c',
#    'name': 'MetLife Stadium',
#    'city': 'East Rutherford',
#    'state': 'NJ',
#    'zipCode': '07073',
#    'elevation': 6.56168,
#    'lastUpdated': '2024-06-17 14:33:26'}},
#  {'id': '2024-21',
#   'teamId': 'philadelphia-eagles',
#   'franchiseId': 21,
#   'season': 2024,
#   'team': {'franchiseId': 21,
#    'guid': 'd1a9b001-1df7-fbd7-ae4c-6ca7065286ec',
#    'uid': 's:20~l:28~t:21',
#    'alternateIds': {'sdr': '8823'},
#    'location': 'Philadelphia',
#    'name': 'Eagles',
#    'nickname': 'Eagles',
#    'abbreviation': 'PHI',
#    'displayName': 'Philadelphia Eagles',
#    'shortDisplayName': 'Eagles',
#    'color': '06424D',
#    'alternateColor': '000000',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3806},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3806?lang=en&region=us',
#    'fullName': 'Lincoln Financial Field',
#    'capacity': None,
#    'grass': True,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3806.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3806.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'lincolnfinancialfield',
#    'lastUpdated': '2024-06-17 14:21:04'},
#   'geocoding': {'requestedAddress': 'Lincoln Financial Field, Philadelphia, PA, 19148',
#    'codedAddress': 'Lincoln Financial Field',
#    'latitude': 39.9016959,
#    'longitude': -75.1676236,
#    'provider': 'ArcGIS',
#    'h3Index': '8f2a134deca381b',
#    'name': 'Lincoln Financial Field',
#    'city': 'Philadelphia',
#    'state': 'PA',
#    'zipCode': '19148',
#    'elevation': 16.4042,
#    'lastUpdated': '2024-06-17 14:32:51'}},
#  {'id': '2024-22',
#   'teamId': 'arizona-cardinals',
#   'franchiseId': 22,
#   'season': 2024,
#   'team': {'franchiseId': 22,
#    'guid': '8fc7b962-95e1-3cb8-6a7d-b499de9ad546',
#    'uid': 's:20~l:28~t:22',
#    'alternateIds': {'sdr': '8801'},
#    'location': 'Arizona',
#    'name': 'Cardinals',
#    'nickname': 'Cardinals',
#    'abbreviation': 'ARI',
#    'displayName': 'Arizona Cardinals',
#    'shortDisplayName': 'Cardinals',
#    'color': 'A40227',
#    'alternateColor': 'ffffff',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3970},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3970?lang=en&region=us',
#    'fullName': 'State Farm Stadium',
#    'capacity': None,
#    'grass': True,
#    'indoor': True,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3970.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3970.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'comfortsuitesstatefarmstadium',
#    'lastUpdated': '2024-06-17 14:23:55'},
#   'geocoding': {'requestedAddress': 'State Farm Stadium, Glendale, AZ',
#    'codedAddress': 'Comfort Suites State Farm Stadium',
#    'latitude': 33.509889,
#    'longitude': -112.2704398,
#    'provider': 'ArcGIS',
#    'h3Index': '8f29b6d66c73942',
#    'name': 'State Farm Stadium',
#    'city': 'Glendale',
#    'state': 'AZ',
#    'zipCode': None,
#    'elevation': 1036.74544,
#    'lastUpdated': '2024-06-17 18:03:19'}},
#  {'id': '2024-23',
#   'teamId': 'pittsburgh-steelers',
#   'franchiseId': 23,
#   'season': 2024,
#   'team': {'franchiseId': 23,
#    'guid': 'debcd592-8d53-71f1-fc15-5c8b8ef9df6e',
#    'uid': 's:20~l:28~t:23',
#    'alternateIds': {'sdr': '8824'},
#    'location': 'Pittsburgh',
#    'name': 'Steelers',
#    'nickname': 'Steelers',
#    'abbreviation': 'PIT',
#    'displayName': 'Pittsburgh Steelers',
#    'shortDisplayName': 'Steelers',
#    'color': '000000',
#    'alternateColor': 'ffb612',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3752},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3752?lang=en&region=us',
#    'fullName': 'Acrisure Stadium',
#    'capacity': None,
#    'grass': True,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3752.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3752.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'acrisurestateadium',
#    'lastUpdated': '2024-06-17 14:20:06'},
#   'geocoding': {'requestedAddress': 'Acrisure Stadium, Pittsburgh, PA, 15212',
#    'codedAddress': 'Acrisure Stadium',
#    'latitude': 40.4458496,
#    'longitude': -80.0152223,
#    'provider': 'ArcGIS',
#    'h3Index': '8f2a847168326c4',
#    'name': 'Acrisure Stadium',
#    'city': 'Pittsburgh',
#    'state': 'PA',
#    'zipCode': '15212',
#    'elevation': 807.08664,
#    'lastUpdated': '2024-06-17 14:31:55'}},
#  {'id': '2024-24',
#   'teamId': 'los-angeles-chargers',
#   'franchiseId': 24,
#   'season': 2024,
#   'team': {'franchiseId': 24,
#    'guid': '84caf62b-c753-71ea-a787-44fd224a4294',
#    'uid': 's:20~l:28~t:24',
#    'alternateIds': {'sdr': '8825'},
#    'location': 'Los Angeles',
#    'name': 'Chargers',
#    'nickname': 'Chargers',
#    'abbreviation': 'LAC',
#    'displayName': 'Los Angeles Chargers',
#    'shortDisplayName': 'Chargers',
#    'color': '042453',
#    'alternateColor': 'ffc20e',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 1423},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/1423?lang=en&region=us',
#    'fullName': 'StubHub Center',
#    'capacity': None,
#    'grass': True,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/1423.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'stubhubctrcarsoncalifornia90747',
#    'lastUpdated': '2024-06-17 14:17:02'},
#   'geocoding': {'requestedAddress': 'StubHub Center, Carson, CA, 90746',
#    'codedAddress': 'StubHub Ctr, Carson, California, 90747',
#    'latitude': 33.862992376894,
#    'longitude': -118.264240720052,
#    'provider': 'ArcGIS',
#    'h3Index': '8f29a56e6891019',
#    'name': 'StubHub Center',
#    'city': 'Carson',
#    'state': 'CA',
#    'zipCode': '90746',
#    'elevation': 55.77428,
#    'lastUpdated': '2024-06-17 14:17:02'}},
#  {'id': '2024-25',
#   'teamId': 'san-francisco-49ers',
#   'franchiseId': 25,
#   'season': 2024,
#   'team': {'franchiseId': 25,
#    'guid': '985a261f-296c-c95c-32a5-addc4df75001',
#    'uid': 's:20~l:28~t:25',
#    'alternateIds': {'sdr': '8826'},
#    'location': 'San Francisco',
#    'name': '49ers',
#    'nickname': '49ers',
#    'abbreviation': 'SF',
#    'displayName': 'San Francisco 49ers',
#    'shortDisplayName': '49ers',
#    'color': '981324',
#    'alternateColor': 'b3995d',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3669},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3669?lang=en&region=us',
#    'fullName': 'Candlestick Park',
#    'capacity': None,
#    'grass': True,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3669.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3669.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'candlestickpark',
#    'lastUpdated': '2024-06-17 14:18:41'},
#   'geocoding': {'requestedAddress': 'Candlestick Park, San Francisco, CA',
#    'codedAddress': 'Candlestick Park',
#    'latitude': 37.7135,
#    'longitude': -122.38443,
#    'provider': 'ArcGIS',
#    'h3Index': '8f2830825c284e3',
#    'name': 'Candlestick Park',
#    'city': 'San Francisco',
#    'state': 'CA',
#    'zipCode': None,
#    'elevation': 9.84252,
#    'lastUpdated': '2024-06-17 14:30:31'}},
#  {'id': '2024-26',
#   'teamId': 'seattle-seahawks',
#   'franchiseId': 26,
#   'season': 2024,
#   'team': {'franchiseId': 26,
#    'guid': '3767a23c-a17d-294f-288a-9086ad1f0680',
#    'uid': 's:20~l:28~t:26',
#    'alternateIds': {'sdr': '8827'},
#    'location': 'Seattle',
#    'name': 'Seahawks',
#    'nickname': 'Seahawks',
#    'abbreviation': 'SEA',
#    'displayName': 'Seattle Seahawks',
#    'shortDisplayName': 'Seahawks',
#    'color': '224970',
#    'alternateColor': '69be28',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3673},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3673?lang=en&region=us',
#    'fullName': 'Lumen Field',
#    'capacity': None,
#    'grass': False,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3673.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3673.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': '98134seattlewashington',
#    'lastUpdated': '2024-06-17 14:18:44'},
#   'geocoding': {'requestedAddress': 'Lumen Field, Seattle, WA, 98134',
#    'codedAddress': '98134, Seattle, Washington',
#    'latitude': 47.5773571,
#    'longitude': -122.3290729,
#    'provider': 'ArcGIS',
#    'h3Index': '8f28d55560c0d16',
#    'name': 'Lumen Field',
#    'city': 'Seattle',
#    'state': 'WA',
#    'zipCode': '98134',
#    'elevation': 52.49344,
#    'lastUpdated': '2024-06-17 14:30:34'}},
#  {'id': '2024-27',
#   'teamId': 'tampa-bay-buccaneers',
#   'franchiseId': 27,
#   'season': 2024,
#   'team': {'franchiseId': 27,
#    'guid': '13e8b157-a75a-ff24-ae91-fa3d52ddf204',
#    'uid': 's:20~l:28~t:27',
#    'alternateIds': {'sdr': '8829'},
#    'location': 'Tampa Bay',
#    'name': 'Buccaneers',
#    'nickname': 'Buccaneers',
#    'abbreviation': 'TB',
#    'displayName': 'Tampa Bay Buccaneers',
#    'shortDisplayName': 'Buccaneers',
#    'color': 'A80D08',
#    'alternateColor': '3e3a35',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3886},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3886?lang=en&region=us',
#    'fullName': 'Raymond James Stadium',
#    'capacity': None,
#    'grass': True,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3886.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3886.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': '33607raymondjamesstateadiumtampaflorida',
#    'lastUpdated': '2024-06-17 14:22:25'},
#   'geocoding': {'requestedAddress': 'Raymond James Stadium, Tampa, FL, 33607',
#    'codedAddress': '33607, Raymond James Stadium, Tampa, Florida',
#    'latitude': 27.98156785,
#    'longitude': -82.50398325,
#    'provider': 'ArcGIS',
#    'h3Index': '8f441a124660740',
#    'name': 'Raymond James Stadium',
#    'city': 'Tampa',
#    'state': 'FL',
#    'zipCode': '33607',
#    'elevation': 52.49344,
#    'lastUpdated': '2024-06-17 14:34:10'}},
#  {'id': '2024-28',
#   'teamId': 'washington-commanders',
#   'franchiseId': 28,
#   'season': 2024,
#   'team': {'franchiseId': 28,
#    'guid': 'fbeaf73e-6d6c-cca4-0809-713d9d741f90',
#    'uid': 's:20~l:28~t:28',
#    'alternateIds': {'sdr': '8831'},
#    'location': 'Washington',
#    'name': 'Commanders',
#    'nickname': 'Commanders',
#    'abbreviation': 'WSH',
#    'displayName': 'Washington Commanders',
#    'shortDisplayName': 'Commanders',
#    'color': '650415',
#    'alternateColor': 'ffb612',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3719},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3719?lang=en&region=us',
#    'fullName': 'FedExField',
#    'capacity': None,
#    'grass': True,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3719.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3719.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'fedexfld',
#    'lastUpdated': '2024-06-17 14:19:30'},
#   'geocoding': {'requestedAddress': 'FedExField, Landover, MD, 20785',
#    'codedAddress': 'Fedex Fld',
#    'latitude': 38.908775,
#    'longitude': -76.866933333,
#    'provider': 'ArcGIS',
#    'h3Index': '8f2aa8469566206',
#    'name': 'FedExField',
#    'city': 'Landover',
#    'state': 'MD',
#    'zipCode': '20785',
#    'elevation': 173.88452,
#    'lastUpdated': '2024-06-17 14:31:21'}},
#  {'id': '2024-29',
#   'teamId': 'carolina-panthers',
#   'franchiseId': 29,
#   'season': 2024,
#   'team': {'franchiseId': 29,
#    'guid': '647c27bf-ab86-550e-5b83-91c29e73e4a9',
#    'uid': 's:20~l:28~t:29',
#    'alternateIds': {'sdr': '8805'},
#    'location': 'Carolina',
#    'name': 'Panthers',
#    'nickname': 'Panthers',
#    'abbreviation': 'CAR',
#    'displayName': 'Carolina Panthers',
#    'shortDisplayName': 'Panthers',
#    'color': '2177B0',
#    'alternateColor': '000000',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3628},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3628?lang=en&region=us',
#    'fullName': 'Bank of America Stadium',
#    'capacity': None,
#    'grass': False,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3628.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3628.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'bankofamericastateadium',
#    'lastUpdated': '2024-06-17 14:17:57'},
#   'geocoding': {'requestedAddress': 'Bank of America Stadium, Charlotte, NC, 28202',
#    'codedAddress': 'Bank of America Stadium',
#    'latitude': 35.2248779,
#    'longitude': -80.8519233,
#    'provider': 'ArcGIS',
#    'h3Index': '8f44d84d8523a95',
#    'name': 'Bank of America Stadium',
#    'city': 'Charlotte',
#    'state': 'NC',
#    'zipCode': '28202',
#    'elevation': 718.50396,
#    'lastUpdated': '2024-06-17 14:29:49'}},
#  {'id': '2024-30',
#   'teamId': 'jacksonville-jaguars',
#   'franchiseId': 30,
#   'season': 2024,
#   'team': {'franchiseId': 30,
#    'guid': 'ca6fb778-cbf6-d9a3-3e93-01230335fcab',
#    'uid': 's:20~l:28~t:30',
#    'alternateIds': {'sdr': '8814'},
#    'location': 'Jacksonville',
#    'name': 'Jaguars',
#    'nickname': 'Jaguars',
#    'abbreviation': 'JAX',
#    'displayName': 'Jacksonville Jaguars',
#    'shortDisplayName': 'Jaguars',
#    'color': '00839C',
#    'alternateColor': 'd7a22a',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3712},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3712?lang=en&region=us',
#    'fullName': 'EverBank Stadium',
#    'capacity': None,
#    'grass': True,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3712.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3712.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'everbank',
#    'lastUpdated': '2024-06-17 14:19:22'},
#   'geocoding': {'requestedAddress': 'EverBank Stadium, Jacksonville, FL, 32202',
#    'codedAddress': 'EverBank',
#    'latitude': 30.3202583,
#    'longitude': -81.6743352,
#    'provider': 'ArcGIS',
#    'h3Index': '8f44f0082acd8f6',
#    'name': 'EverBank Stadium',
#    'city': 'Jacksonville',
#    'state': 'FL',
#    'zipCode': '32202',
#    'elevation': 0.0,
#    'lastUpdated': '2024-06-17 14:31:14'}},
#  {'id': '2024-33',
#   'teamId': 'baltimore-ravens',
#   'franchiseId': 33,
#   'season': 2024,
#   'team': {'franchiseId': 33,
#    'guid': '38248455-3da4-84e4-8090-98b5cc38ffdc',
#    'uid': 's:20~l:28~t:33',
#    'alternateIds': {'sdr': '8803'},
#    'location': 'Baltimore',
#    'name': 'Ravens',
#    'nickname': 'Ravens',
#    'abbreviation': 'BAL',
#    'displayName': 'Baltimore Ravens',
#    'shortDisplayName': 'Ravens',
#    'color': '2B025B',
#    'alternateColor': '000000',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3814},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3814?lang=en&region=us',
#    'fullName': 'M&T Bank Stadium',
#    'capacity': None,
#    'grass': True,
#    'indoor': False,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3814.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3814.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'mtbankstateadium',
#    'lastUpdated': '2024-06-17 14:21:12'},
#   'geocoding': {'requestedAddress': 'M&T Bank Stadium, Baltimore, MD, 21230',
#    'codedAddress': 'M & T Bank Stadium',
#    'latitude': 39.276905,
#    'longitude': -76.6227764,
#    'provider': 'ArcGIS',
#    'h3Index': '8f2aa8c0da663ab',
#    'name': 'M&T Bank Stadium',
#    'city': 'Baltimore',
#    'state': 'MD',
#    'zipCode': '21230',
#    'elevation': 26.24672,
#    'lastUpdated': '2024-06-17 14:33:00'}},
#  {'id': '2024-34',
#   'teamId': 'houston-texans',
#   'franchiseId': 34,
#   'season': 2024,
#   'team': {'franchiseId': 34,
#    'guid': '595690b3-2161-4913-a7a7-814af2fd2621',
#    'uid': 's:20~l:28~t:34',
#    'alternateIds': {'sdr': '13974'},
#    'location': 'Houston',
#    'name': 'Texans',
#    'nickname': 'Texans',
#    'abbreviation': 'HOU',
#    'displayName': 'Houston Texans',
#    'shortDisplayName': 'Texans',
#    'color': '00133F',
#    'alternateColor': 'c41230',
#    'isActive': True,
#    'isAllStar': False,
#    'college': None,
#    'venueId': 3891},
#   'venue': {'ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/venues/3891?lang=en&region=us',
#    'fullName': 'NRG Stadium',
#    'capacity': None,
#    'grass': False,
#    'indoor': True,
#    'images': [{'href': 'https://a.espncdn.com/i/venues/nfl/day/3891.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day'],
#      'lastUpdated': None},
#     {'href': 'https://a.espncdn.com/i/venues/nfl/day/interior/3891.jpg',
#      'width': 2000,
#      'height': 1125,
#      'alt': '',
#      'rel': ['full', 'day', 'interior'],
#      'lastUpdated': None}],
#    'geocodingId': 'nrgstateadium',
#    'lastUpdated': '2024-06-17 14:22:30'},
#   'geocoding': {'requestedAddress': 'NRG Stadium, Houston, TX, 77054',
#    'codedAddress': 'NRG Stadium',
#    'latitude': 29.6860598,
#    'longitude': -95.4108751,
#    'provider': 'ArcGIS',
#    'h3Index': '8f446ca8540c16d',
#    'name': 'NRG Stadium',
#    'city': 'Houston',
#    'state': 'TX',
#    'zipCode': '77054',
#    'elevation': 62.33596,
#    'lastUpdated': '2024-06-17 18:03:15'}}]

# %%
from espn_api_orm.consts import ESPNSportLeagueTypes
for i in ESPNSportLeagueTypes:
    print(i.value)
# Out:
# baseball/college-baseball
# baseball/college-softball
# baseball/mlb
# basketball/mens-college-basketball
# basketball/nba
# basketball/wnba
# basketball/womens-college-basketball
# field-hockey/womens-college-field-hockey
# football/college-football
# football/nfl
# golf/liv
# golf/lpga
# golf/pga
# hockey/mens-college-hockey
# hockey/nhl
# hockey/womens-college-hockey
# lacrosse/mens-college-lacrosse
# lacrosse/pll
# lacrosse/womens-college-lacrosse
# mma/ufc
# soccer/uefa.champions
# soccer/eng.1
# soccer/esp.1
# soccer/ger.1
# soccer/usa.1
# soccer/ita.1
# soccer/fra.1
# soccer/eng.2
# soccer/ned.1
# soccer/por.1
# volleyball/mens-college-volleyball
# volleyball/womens-college-volleyball
# water-polo/mens-college-water-polo
# water-polo/womens-college-water-polo
