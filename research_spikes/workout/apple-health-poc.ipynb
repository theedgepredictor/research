# %% [markdown]
# # Apple Health POC
#
# [End to End ETL Pipeline](https://medium.com/@ericfflynn/a-cloud-based-etl-pipeline-apple-health-data-to-mysql-48391576ce8e)
#
# [Health Auto Export Docs](https://github.com/Lybron/health-auto-export)
#
# [Streamlit Visual Example](https://github.com/ericfflynn/health-app/blob/main/Home.py)
#
# [Elasticsearch Visual Example](https://github.com/markwk/qs_ledger/tree/master/apple_health)
#
# [Python Apple Health Package](https://github.com/fedecalendino/apple-health)
#
# This PoC will outline collecting data from Apple Health and preprocessing it for visualization. The current process will handle processing the `export.xml` file from Apple Health (retrieved from IPhone). Once we can confirm that the data is extracted, transformed and loaded again properly we will move on to the next step. I want to do some analysis into the Apple Health Kit to see all of the potential XML tags that can be extracted. I want to build my own data pipeline to process the data.
#
#
# 1. Config
#
# 2. Extract data
#
# 3. Transform/Preprocess Data
#
# 4. Load data (as parquet)
#
# 5. Build weekly calendar workout

# %% [markdown]
# ## 1. Config

# %%
ROOT_DIR = '../../data/workout/'
import datetime
import pandas as pd
from health import HealthData
from consts import *
import xmltodict
import re

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

def _parse_float(value, default=None):
    if value is None:
        return default
    
    if value in HK_CONSTANTS:
        return HK_CONSTANTS[value]

    try:
        return float(value)
    except (ValueError, TypeError):
        return default
    
def _parse_date(value):
    if value is None:
        return None
    if type(value) == datetime.datetime:
        return value
    return pd.Timestamp(value).to_pydatetime()

def _clean_string(s):
    if isinstance(s, str):
        return re.sub("[\W_]+",'',s).upper().replace('Â','')
    else:
        return s
    
def _parse_source_id(source_name):
    source_id = _clean_string(source_name)
    return source_id

def _parse_device_string(device_string):
    # Split on commas
    components = device_string.split(',')

    # Initialize the dictionary to store key-value pairs
    device_info = {}
    
    # Initialize variables to hold the key and value
    current_key = None
    current_value = []

    # Process each component
    for component in components:
        # Split on colon to separate key and value
        if ':' in component:
            if current_key is not None:
                # Join the current value parts and store in the dictionary
                device_info[current_key.strip()] = '.'.join(current_value).strip()
            # Split into key and value parts
            key, value = component.split(':', 1)
            current_key = key.replace('&lt;','').replace('>','').replace('<','')
            current_value = [value]
        else:
            # Append the current component to the value list
            current_value.append(component)
    
    # Store the last key-value pair
    if current_key is not None:
        device_info[current_key.strip()] = ':'.join(current_value).strip()

    return device_info

TYPE = "@type"
SOURCE_NAME = "@sourceName"
SOURCE_VERSION = "@sourceVersion"
DEVICE = "@device"
CREATION_DATE = "@creationDate"
START_DATE = "@startDate"
END_DATE = "@endDate"
DATE = '@date'
UNIT = "@unit"
BPM = "@bpm"
TIME = "@time"

KEY = "@key"
VALUE = "@value"
MIN='@minimum'
MAX='@maximum'
AVG='@average'
SUM='@sum'

# %% [markdown]
# ## 2. Extract data
#
# **Record**
#
#
# **Activity Summary**
#
#
# **Workout**
#
#
# **Config**

# %%
file = ROOT_DIR + 'export.xml'

with open(file) as file:
    xml = xmltodict.parse(file.read())
    data = xml["HealthData"]

# %%
file = ROOT_DIR + 'export.xml'

class HealthKitData:
    '''
    XML HealthKit data. All data is sorted by date low-to-high
    '''
    def __init__(self, file):
        if type(file) == dict:
            self.data = file
        else:
            self.file = file
            self.config = {}
            self.data = None
            with open(file) as file:
                xml = xmltodict.parse(file.read())
                self.data = xml["HealthData"]
        self.config = self._get_config()
        self.activity_summaries = self._get_activity_summaries()
        self.workouts = self._get_workouts()
        self.records = self._get_records()

    def get_workouts(self, workout_type=None, source_type=None, start_date=None, end_date=None):
        start_date = _parse_date(start_date)
        end_date = _parse_date(end_date)
        for w in self.workouts:
            if workout_type is not None and w['workout_type'] != workout_type:
                continue
            if source_type is not None and self.config['sources'][w['source_id']] != source_type:
                continue
            if start_date is not None and _parse_date(w['start_date_str']) < start_date:
                continue
            if end_date and _parse_date(w['start_date_str']) > end_date:
                continue
            yield w

    def get_records(self, record_type=None, source_type=None, start_date=None, end_date=None):
        for w in self.records:
            if record_type is not None and w['workout_type'] != record_type:
                continue
            if source_type is not None and self.config['sources'][w['source_id']] != source_type:
                continue
            if start_date is not None and _parse_date(w['start_date_str']) < start_date:
                continue
            if end_date and _parse_date(w['start_date_str']) > end_date:
                continue
            yield w

    def set_sources(self, sources):
        self.config['sources'] = sources

    def _get_records(self):
        """
        Parse Records from Payload
        Return a dict
        """
        sources = {}

        records = self.data['Record']#self.data.pop('Records', {})
        out = []
        for r in records:
            rec = Record(**r)
            sources.update(self._parse_source(r))
            out.append(rec.__dict__)

        self.set_sources(sources)
        return out
    
    def _parse_source(self, data):
        """
        Parse Sources from Payload
        Return a dict
        """
        source_name = data.get(SOURCE_NAME)

        source_type = "UNKNOWN"
        if 'WATCH' in source_name.upper():
            source_type = 'WATCH'
        elif 'RENPHO' in source_name.upper():
            source_type = 'SCALE'
        elif 'PHONE' in source_name.upper():
            source_type = 'PHONE'
        elif 'MYFITNESSPAL' in source_name.upper():
            source_type = 'APP'
        elif 'HEALTH' in source_name.upper():
            source_type = 'APP' # manually entered value into health app
        elif 'STRONG' in source_name.upper():
            source_type = 'APP'
        elif 'SLEEP' in source_name.upper():
            source_type = 'APP'
            
        source_version = data.get(SOURCE_VERSION, None)
        source_id = _parse_source_id(source_name)
        device = data.get(DEVICE,None)
        source = {
            "source_name":source_name,
            "source_version": source_version,
            "source_type": source_type,
        }
        if device is not None:
            source = {
                **source,
                **_parse_device_string(device)
            }
            
        return {source_id: source}
        
        
    def _get_config(self):
        """
        Parse Config from Payload from Me, ExportDate and Unique Devices found in Records
        Return a dict
        """
        me = self.data['Me']#self.data.pop('Me', {})
        export_date = self.data['ExportDate']#self.data.pop('ExportDate', {})
        dob = datetime.datetime.strptime(me.get(HK_ME_DATE_OF_BIRTH), "%Y-%m-%d")
        
        return {
            'date_of_birth': dob,
            'age': (datetime.datetime.now() - dob).days // 365,
            'biological_sex': me.get(HK_ME_BIOLOGICAL_SEX),
            'blood_type': me.get(HK_ME_BLOOD_TYPE),
            'skin_type': me.get(HK_ME_SKIN_TYPE),
            'wheelchair_use': me.get(HK_ME_WHEELCHAIR_USE),
            'sources': {},
            'last_updated': pd.Timestamp(export_date['@value']).to_pydatetime(), 
        }
    
    def _get_activity_summaries(self):
        """
        Parse ActivitySummaries from Payload
        Return a dict of {date: {key: value}}
        """
        activity_summaries = self.data['ActivitySummary']#self.data.pop('ActivitySummary', {})
        parsed = {}
        for activity_summary in activity_summaries:
            date = activity_summary.get(DATE_COMPONENTS)
            parsed[date] = {
                'active_energy_burned': _parse_float(activity_summary.get(ACTIVE_ENERGY_BURNED, None)),
                'active_energy_burned_goal': _parse_float(activity_summary.get(ACTIVE_ENERGY_BURNED_GOAL, None)),
                'active_energy_burned_unit': activity_summary.get(ACTIVE_ENERGY_BURNED_UNIT, "Cal"),
                'exercise_time': _parse_float(activity_summary.get(APPLE_EXERCISE_TIME, None)),
                'exercise_time_goal': _parse_float(activity_summary.get(APPLE_EXERCISE_TIME_GOAL, None)),
                'stand_hours': _parse_float(activity_summary.get(APPLE_STAND_HOURS, None)),
                'stand_hours_goal': _parse_float(activity_summary.get(APPLE_STAND_HOURS_GOAL, None)),
            }
        return parsed
    
    def _get_workouts(self):
        workouts = self.data['Workout']#self.data.pop('Workout', {})
        return [Workout(**w).__dict__ for w in workouts]

class Record:
    NAME_KEY = TYPE
    def __init__(self, **data):
        """
        Parse a Record from the Payload, handle metadata creation and source_id
        """
        self.name: str = data[self.NAME_KEY]
        self.source_id = _parse_source_id(data.get(SOURCE_NAME))
        self.created_at: datetime = _parse_date(data.get(CREATION_DATE, None))
        self.start: datetime = _parse_date(data.get(START_DATE))
        self.start_date_str: str = self.start.strftime("%Y-%m-%d")
        self.end: datetime = _parse_date(data.get(END_DATE))
        self.unit: str = data.get(UNIT, None)
        self.value: float = _parse_float(data.get(VALUE, None))
        self.heartrate_variability = []

        metadata = data.get("MetadataEntry", None)
        if metadata is None:
            self.metadata = []
        elif isinstance(metadata, dict):
            self.metadata = [self._parse_metadata(metadata)]
        elif isinstance(metadata, list):
            self.metadata = list(map(lambda m: self._parse_metadata(m), metadata))
        
        heartrate_variability = data.get("HeartRateVariabilityMetadataList", None)
        if heartrate_variability is not None:
            heartrate_variability = heartrate_variability.get("InstantaneousBeatsPerMinute", None)
            self.heartrate_variability = list(map(lambda m: self._parse_heartrate_variability(m), heartrate_variability))

    def _parse_metadata(self, data):
        return {'key':data.get(KEY), 'value': data.get(VALUE)}
    
    def _parse_heartrate_variability(self, data):
        return {'bpm':data.get(BPM), 'time': _parse_date(data.get(TIME))}

class Workout(Record):
    NAME_KEY = WORKOUT_ACTIVITY_TYPE
    def __init__(self, **data):
        super().__init__(**data)
        self.duration: float = _parse_float(data.get(DURATION))
        self.duration_unit: str = data.get(DURATION_UNIT)

        self.distance: float = _parse_float(data.get(TOTAL_DISTANCE, None))
        self.distance_unit: str = data.get(TOTAL_DISTANCE_UNIT, 'mi')

        self.energy_burned: float = _parse_float(data.get(TOTAL_ENERGY_BURNED, None))
        self.energy_burned_unit: str = data.get(TOTAL_ENERGY_BURNED_UNIT, 'Cal')

        self.flights_climbed: float = _parse_float(data.get(TOTAL_FLIGHTS_CLIMBED))
        self.swimming_strokes: float = _parse_float(data.get(TOTAL_SWIMMING_STROKE_COUNT))
        self.events=[]
        self.statistics=[]
        self.route=None

        workout_events = data.get("WorkoutEvent", None)
        if workout_events is not None:
            if isinstance(workout_events, dict):
                self.events = [self._parse_workout_event(workout_events)]
            else:
                self.events = list(map(lambda m: self._parse_workout_event(m), workout_events))

        workout_statistics = data.get("WorkoutStatistics", None)
        if workout_statistics is not None:
            if isinstance(workout_statistics, dict):
                self.statistics = [self._parse_workout_statistic(workout_statistics)]
            else:
                self.statistics = list(map(lambda m: self._parse_workout_statistic(m), workout_statistics))
    
        workout_route = data.get("WorkoutRoute", None)
        if workout_route is not None:
            self.route = self._parse_workout_route(workout_route)

        if self.distance is None or self.distance_unit is None:
            statistic = self.get_statistic(HK_RECORD_DISTANCE_WALKING_RUNNING)
            if statistic is not None:
                self.distance = statistic['sum'] if statistic['sum']  is not None else None
                self.distance_unit = statistic['unit'] if statistic['unit'] is not None else 'mi'

        if self.energy_burned is None or self.energy_burned_unit is None:
            statistic = self.get_statistic(HK_RECORD_ACTIVE_ENERGY_BURNED)
            if statistic is not None:
                self.energy_burned = statistic['sum'] if statistic['sum'] is not None else None
                self.energy_burned_unit = statistic['unit'] if statistic['unit'] is not None else 'Cal'
            
    def get_statistic(self, statistic_type):
        for s in self.statistics:
            if s['name'] == statistic_type:
                return s
        return None
    
    def get_event(self, event_type):
        for s in self.events:
            if s['name'] == event_type:
                return s
        return None

    def _parse_workout_event(self, data):
        return {
            'name': data.get(TYPE),
            'date': _parse_date(data.get(DATE)),
            'duration': _parse_float(data.get(DURATION)),
            'duration_unit': data.get(DURATION_UNIT),
        }
    
    def _parse_workout_statistic(self, data):
        statistic_type = "SUM" if data.get(SUM,None) is not None else "AVG" 
        return {
            'name': data.get(TYPE),
            'type': statistic_type,
            'start_date': _parse_date(data.get(START_DATE, None)),
            'end_date': _parse_date(data.get(END_DATE, None)),
            'sum': _parse_float(data.get(SUM, None)),
            'average': _parse_float(data.get(AVG, None)),
            'min': _parse_float(data.get(MIN, None)),
            'max': _parse_float(data.get(MAX, None)),
            'unit': _parse_float(data.get(UNIT, None)),
        }
    
    def _parse_workout_route(self, data):
        file_reference = data.get("FileReference", None)
        file_path = file_reference.get("@path", None)
        metadata = data.get("MetadataEntry", None)
        if metadata is None:
            metadata = []
        elif isinstance(metadata, dict):
            metadata = [self._parse_metadata(metadata)]
        elif isinstance(metadata, list):
            metadata = list(map(lambda m: self._parse_metadata(m), metadata))

        return {
            'file_path': file_path,
            'file_name': file_path.split("/")[-1],
            'metadata': metadata,
        }
    
    def save():
        

    
hkd = HealthKitData(data)
#hkd.workouts[-6]

# %%
hkd.config['sources']
# Out:
# {'RENPHO': {'source_name': 'Renpho',
#   'source_version': '1',
#   'source_type': 'SCALE'},
#  'RENPHOHEALTH': {'source_name': 'Renpho Health',
#   'source_version': '32',
#   'source_type': 'SCALE'},
#  'HEALTH': {'source_name': 'Health',
#   'source_version': '16.2',
#   'source_type': 'APP'},
#  'MYFITNESSPAL': {'source_name': 'MyFitnessPal',
#   'source_version': '46391',
#   'source_type': 'APP'},
#  'CHARLIESAPPLEWATCH': {'source_name': 'Charlieâ€™s AppleÂ\xa0Watch',
#   'source_version': '9.6.3',
#   'source_type': 'WATCH',
#   'HKDevice': '0x28063def0>',
#   'name': 'Apple Watch',
#   'manufacturer': 'Apple Inc.',
#   'model': 'Watch',
#   'hardware': 'Watch6.13',
#   'software': '9.6.3>'},
#  'CHARLIESIPHONE': {'source_name': 'Charlieâ€™s iPhone',
#   'source_version': '16.7.2',
#   'source_type': 'PHONE'},
#  'STRONG': {'source_name': 'Strong',
#   'source_version': '7269',
#   'source_type': 'APP'},
#  'SLEEP': {'source_name': 'Sleep',
#   'source_version': '9.0',
#   'source_type': 'APP'}}

# %%
a = list(hkd.get_workouts(start_date='2024-07-01', end_date='2024-07-30'))
a
# Out:
# [{'name': 'HKWorkoutActivityTypeTraditionalStrengthTraining',
#   'source_id': 'CHARLIESAPPLEWATCH',
#   'created_at': datetime.datetime(2024, 7, 1, 13, 27, 51, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start': datetime.datetime(2024, 7, 1, 11, 59, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start_date_str': '2024-07-01',
#   'end': datetime.datetime(2024, 7, 1, 13, 27, 46, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'unit': None,
#   'value': None,
#   'heartrate_variability': [],
#   'metadata': [{'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKAverageMETs', 'value': '6.49148 kcal/hrÂ·kg'},
#    {'key': 'HKWeatherTemperature', 'value': '85.082 degF'},
#    {'key': 'HKWeatherHumidity', 'value': '7500 %'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKAverageMETs', 'value': '6.49148 kcal/hrÂ·kg'},
#    {'key': 'HKWeatherTemperature', 'value': '85.082 degF'},
#    {'key': 'HKWeatherHumidity', 'value': '7500 %'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'}],
#   'duration': 87.7823065340519,
#   'duration_unit': 'min',
#   'distance': None,
#   'distance_unit': 'mi',
#   'energy_burned': 744.376,
#   'energy_burned_unit': 'Cal',
#   'flights_climbed': None,
#   'swimming_strokes': None,
#   'events': [],
#   'statistics': [{'name': 'HKQuantityTypeIdentifierActiveEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 1, 11, 59, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 1, 13, 27, 46, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 744.376,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierHeartRate',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 1, 11, 59, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 1, 13, 27, 46, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 123.026,
#     'min': 63.0,
#     'max': 177.0,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierBasalEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 1, 11, 59, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 1, 13, 27, 46, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 160.606,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None}],
#   'route': None},
#  {'name': 'HKWorkoutActivityTypeRunning',
#   'source_id': 'CHARLIESAPPLEWATCH',
#   'created_at': datetime.datetime(2024, 7, 2, 18, 0, 57, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start': datetime.datetime(2024, 7, 2, 17, 16, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start_date_str': '2024-07-02',
#   'end': datetime.datetime(2024, 7, 2, 18, 0, 49, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'unit': None,
#   'value': None,
#   'heartrate_variability': [],
#   'metadata': [{'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKWeatherHumidity', 'value': '6900 %'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKWeatherTemperature', 'value': '88.304 degF'},
#    {'key': 'HKAverageMETs', 'value': '7.87775 kcal/hrÂ·kg'},
#    {'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKWeatherHumidity', 'value': '6900 %'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKWeatherTemperature', 'value': '88.304 degF'},
#    {'key': 'HKAverageMETs', 'value': '7.87775 kcal/hrÂ·kg'}],
#   'duration': 44.6082606335481,
#   'duration_unit': 'min',
#   'distance': 3.06249,
#   'distance_unit': 'mi',
#   'energy_burned': 421.868,
#   'energy_burned_unit': 'Cal',
#   'flights_climbed': None,
#   'swimming_strokes': None,
#   'events': [{'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 2, 17, 16, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 8.374712127447129,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 2, 17, 16, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 12.82885740001996,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeMotionResumed',
#     'date': datetime.datetime(2024, 7, 2, 17, 16, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': None,
#     'duration_unit': None},
#    {'name': 'HKWorkoutEventTypeMotionPaused',
#     'date': datetime.datetime(2024, 7, 2, 17, 21, 15, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': None,
#     'duration_unit': None},
#    {'name': 'HKWorkoutEventTypeMotionResumed',
#     'date': datetime.datetime(2024, 7, 2, 17, 21, 22, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': None,
#     'duration_unit': None},
#    {'name': 'HKWorkoutEventTypeMotionPaused',
#     'date': datetime.datetime(2024, 7, 2, 17, 21, 27, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': None,
#     'duration_unit': None},
#    {'name': 'HKWorkoutEventTypeMotionResumed',
#     'date': datetime.datetime(2024, 7, 2, 17, 21, 29, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': None,
#     'duration_unit': None},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 2, 17, 24, 35, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 7.674374183019002,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 2, 17, 29, 2, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 14.38384398818016,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 2, 17, 32, 16, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 9.336633682250977,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeMotionPaused',
#     'date': datetime.datetime(2024, 7, 2, 17, 37, 8, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': None,
#     'duration_unit': None},
#    {'name': 'HKWorkoutEventTypeMotionResumed',
#     'date': datetime.datetime(2024, 7, 2, 17, 37, 19, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': None,
#     'duration_unit': None},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 2, 17, 41, 36, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 9.524368262290954,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 2, 17, 43, 25, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 15.94636029998461,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 2, 17, 51, 7, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 9.628182150920232,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 2, 17, 59, 22, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 1.379208717743556,
#     'duration_unit': 'min'}],
#   'statistics': [{'name': 'HKQuantityTypeIdentifierStepCount',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 2, 17, 16, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 2, 18, 0, 49, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 6210.0,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierRunningGroundContactTime',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 2, 17, 16, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 2, 18, 0, 49, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 302.364,
#     'min': 246.0,
#     'max': 367.0,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierRunningPower',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 2, 17, 16, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 2, 18, 0, 49, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 160.403,
#     'min': 64.0,
#     'max': 276.0,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierActiveEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 2, 17, 16, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 2, 18, 0, 49, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 421.868,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierBasalEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 2, 17, 16, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 2, 18, 0, 49, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 82.779,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierRunningVerticalOscillation',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 2, 17, 16, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 2, 18, 0, 49, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 10.4389,
#     'min': 9.3,
#     'max': 11.3,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierRunningSpeed',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 2, 17, 16, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 2, 18, 0, 49, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 4.16036,
#     'min': 0.778587,
#     'max': 7.32256,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierRunningStrideLength',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 2, 17, 16, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 2, 18, 0, 49, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 0.798614,
#     'min': 0.68,
#     'max': 1.02,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierDistanceWalkingRunning',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 2, 17, 16, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 2, 18, 0, 49, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 3.06249,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierHeartRate',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 2, 17, 16, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 2, 18, 0, 49, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 155.909,
#     'min': 119.0,
#     'max': 181.0,
#     'unit': None}],
#   'route': {'file_path': '/workout-routes/route_2024-07-02_6.00pm.gpx',
#    'file_name': 'route_2024-07-02_6.00pm.gpx',
#    'metadata': [{'key': 'HKMetadataKeySyncVersion', 'value': '2'},
#     {'key': 'HKMetadataKeySyncIdentifier',
#      'value': 'D4236E2B-8E9F-4CCE-B5BF-458C8A7B6BEF'}]}},
#  {'name': 'HKWorkoutActivityTypeWalking',
#   'source_id': 'CHARLIESAPPLEWATCH',
#   'created_at': datetime.datetime(2024, 7, 3, 8, 38, 5, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start': datetime.datetime(2024, 7, 3, 7, 39, 22, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start_date_str': '2024-07-03',
#   'end': datetime.datetime(2024, 7, 3, 8, 38, 1, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'unit': None,
#   'value': None,
#   'heartrate_variability': [],
#   'metadata': [{'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKWeatherHumidity', 'value': '9300 %'},
#    {'key': 'HKWeatherTemperature', 'value': '77.324 degF'},
#    {'key': 'HKAverageMETs', 'value': '4.7853 kcal/hrÂ·kg'},
#    {'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKWeatherHumidity', 'value': '9300 %'},
#    {'key': 'HKWeatherTemperature', 'value': '77.324 degF'},
#    {'key': 'HKAverageMETs', 'value': '4.7853 kcal/hrÂ·kg'}],
#   'duration': 58.64358631571134,
#   'duration_unit': 'min',
#   'distance': 2.50517,
#   'distance_unit': 'mi',
#   'energy_burned': 295.222,
#   'energy_burned_unit': 'Cal',
#   'flights_climbed': None,
#   'swimming_strokes': None,
#   'events': [{'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 3, 7, 39, 22, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 15.35241201718648,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 3, 7, 39, 22, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 23.96242461005847,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 3, 7, 54, 43, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 15.42683340708415,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 3, 8, 3, 20, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 24.69021253188451,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 3, 8, 10, 9, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 15.71306964556376,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 3, 8, 25, 52, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 10.34266209204992,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 3, 8, 28, 1, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 9.601559656858445,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 3, 8, 36, 12, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 1.419219636917114,
#     'duration_unit': 'min'}],
#   'statistics': [{'name': 'HKQuantityTypeIdentifierDistanceWalkingRunning',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 3, 7, 39, 22, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 3, 8, 38, 1, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 2.50517,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierBasalEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 3, 7, 39, 22, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 3, 8, 38, 1, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 108.838,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierHeartRate',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 3, 7, 39, 22, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 3, 8, 38, 1, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 91.4003,
#     'min': 73.0,
#     'max': 129.0,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierActiveEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 3, 7, 39, 22, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 3, 8, 38, 1, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 295.222,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None}],
#   'route': {'file_path': '/workout-routes/route_2024-07-03_8.38am.gpx',
#    'file_name': 'route_2024-07-03_8.38am.gpx',
#    'metadata': [{'key': 'HKMetadataKeySyncVersion', 'value': '2'},
#     {'key': 'HKMetadataKeySyncIdentifier',
#      'value': '808313C6-8E19-4B8F-A964-BBC5B26C38B2'}]}},
#  {'name': 'HKWorkoutActivityTypeTraditionalStrengthTraining',
#   'source_id': 'CHARLIESAPPLEWATCH',
#   'created_at': datetime.datetime(2024, 7, 3, 9, 37, 14, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start': datetime.datetime(2024, 7, 3, 8, 38, 16, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start_date_str': '2024-07-03',
#   'end': datetime.datetime(2024, 7, 3, 9, 37, 11, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'unit': None,
#   'value': None,
#   'heartrate_variability': [],
#   'metadata': [{'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKAverageMETs', 'value': '8.1101 kcal/hrÂ·kg'},
#    {'key': 'HKWeatherTemperature', 'value': '79.592 degF'},
#    {'key': 'HKWeatherHumidity', 'value': '8900 %'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKAverageMETs', 'value': '8.1101 kcal/hrÂ·kg'},
#    {'key': 'HKWeatherTemperature', 'value': '79.592 degF'},
#    {'key': 'HKWeatherHumidity', 'value': '8900 %'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'}],
#   'duration': 58.91464201807976,
#   'duration_unit': 'min',
#   'distance': None,
#   'distance_unit': 'mi',
#   'energy_burned': 616.466,
#   'energy_burned_unit': 'Cal',
#   'flights_climbed': None,
#   'swimming_strokes': None,
#   'events': [],
#   'statistics': [{'name': 'HKQuantityTypeIdentifierActiveEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 3, 8, 38, 16, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 3, 9, 37, 11, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 616.466,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierHeartRate',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 3, 8, 38, 16, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 3, 9, 37, 11, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 133.949,
#     'min': 79.0,
#     'max': 163.0,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierBasalEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 3, 8, 38, 16, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 3, 9, 37, 11, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 108.621,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None}],
#   'route': None},
#  {'name': 'HKWorkoutActivityTypeWalking',
#   'source_id': 'CHARLIESAPPLEWATCH',
#   'created_at': datetime.datetime(2024, 7, 3, 9, 52, 49, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start': datetime.datetime(2024, 7, 3, 9, 37, 19, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start_date_str': '2024-07-03',
#   'end': datetime.datetime(2024, 7, 3, 9, 52, 47, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'unit': None,
#   'value': None,
#   'heartrate_variability': [],
#   'metadata': [{'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKWeatherHumidity', 'value': '8300 %'},
#    {'key': 'HKWeatherTemperature', 'value': '83.138 degF'},
#    {'key': 'HKAverageMETs', 'value': '6.59829 kcal/hrÂ·kg'},
#    {'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKWeatherHumidity', 'value': '8300 %'},
#    {'key': 'HKWeatherTemperature', 'value': '83.138 degF'},
#    {'key': 'HKAverageMETs', 'value': '6.59829 kcal/hrÂ·kg'}],
#   'duration': 15.46986548304558,
#   'duration_unit': 'min',
#   'distance': 0.946636,
#   'distance_unit': 'mi',
#   'energy_burned': 116.938,
#   'energy_burned_unit': 'Cal',
#   'flights_climbed': None,
#   'swimming_strokes': None,
#   'events': [{'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 3, 9, 37, 19, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 10.8217626452446,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 3, 9, 48, 9, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 4.529945701360703,
#     'duration_unit': 'min'}],
#   'statistics': [{'name': 'HKQuantityTypeIdentifierDistanceWalkingRunning',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 3, 9, 37, 19, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 3, 9, 52, 47, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 0.946636,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierBasalEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 3, 9, 37, 19, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 3, 9, 52, 47, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 28.5353,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierHeartRate',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 3, 9, 37, 19, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 3, 9, 52, 47, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 135.666,
#     'min': 121.0,
#     'max': 171.0,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierActiveEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 3, 9, 37, 19, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 3, 9, 52, 47, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 116.938,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None}],
#   'route': {'file_path': '/workout-routes/route_2024-07-03_9.52am.gpx',
#    'file_name': 'route_2024-07-03_9.52am.gpx',
#    'metadata': [{'key': 'HKMetadataKeySyncVersion', 'value': '2'},
#     {'key': 'HKMetadataKeySyncIdentifier',
#      'value': '778610A5-CB29-4782-BDE9-1CADE7230336'}]}},
#  {'name': 'HKWorkoutActivityTypePickleball',
#   'source_id': 'CHARLIESAPPLEWATCH',
#   'created_at': datetime.datetime(2024, 7, 3, 18, 21, 33, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start': datetime.datetime(2024, 7, 3, 17, 17, 47, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start_date_str': '2024-07-03',
#   'end': datetime.datetime(2024, 7, 3, 18, 21, 29, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'unit': None,
#   'value': None,
#   'heartrate_variability': [],
#   'metadata': [{'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKAverageMETs', 'value': '10.673 kcal/hrÂ·kg'},
#    {'key': 'HKWeatherTemperature', 'value': '89.294 degF'},
#    {'key': 'HKWeatherHumidity', 'value': '6900 %'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKAverageMETs', 'value': '10.673 kcal/hrÂ·kg'},
#    {'key': 'HKWeatherTemperature', 'value': '89.294 degF'},
#    {'key': 'HKWeatherHumidity', 'value': '6900 %'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'}],
#   'duration': 63.70669251680374,
#   'duration_unit': 'min',
#   'distance': None,
#   'distance_unit': 'mi',
#   'energy_burned': 866.573,
#   'energy_burned_unit': 'Cal',
#   'flights_climbed': None,
#   'swimming_strokes': None,
#   'events': [],
#   'statistics': [{'name': 'HKQuantityTypeIdentifierActiveEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 3, 17, 17, 47, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 3, 18, 21, 29, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 866.573,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierHeartRate',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 3, 17, 17, 47, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 3, 18, 21, 29, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 157.6,
#     'min': 91.0,
#     'max': 194.0,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierBasalEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 3, 17, 17, 47, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 3, 18, 21, 29, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 117.308,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None}],
#   'route': None},
#  {'name': 'HKWorkoutActivityTypeRunning',
#   'source_id': 'CHARLIESAPPLEWATCH',
#   'created_at': datetime.datetime(2024, 7, 4, 11, 42, 57, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start': datetime.datetime(2024, 7, 4, 11, 28, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start_date_str': '2024-07-04',
#   'end': datetime.datetime(2024, 7, 4, 11, 42, 54, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'unit': None,
#   'value': None,
#   'heartrate_variability': [],
#   'metadata': [{'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKWeatherHumidity', 'value': '6800 %'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKWeatherTemperature', 'value': '88.7 degF'},
#    {'key': 'HKAverageMETs', 'value': '7.73034 kcal/hrÂ·kg'},
#    {'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKWeatherHumidity', 'value': '6800 %'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKWeatherTemperature', 'value': '88.7 degF'},
#    {'key': 'HKAverageMETs', 'value': '7.73034 kcal/hrÂ·kg'}],
#   'duration': 13.91858484943708,
#   'duration_unit': 'min',
#   'distance': 0.954367,
#   'distance_unit': 'mi',
#   'energy_burned': 129.207,
#   'energy_burned_unit': 'Cal',
#   'flights_climbed': None,
#   'swimming_strokes': None,
#   'events': [{'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 4, 11, 28, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 7.464964610338211,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeMotionResumed',
#     'date': datetime.datetime(2024, 7, 4, 11, 29, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': None,
#     'duration_unit': None},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 4, 11, 36, 27, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 5.139094905058543,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeMotionPaused',
#     'date': datetime.datetime(2024, 7, 4, 11, 40, 32, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': None,
#     'duration_unit': None},
#    {'name': 'HKWorkoutEventTypeMotionResumed',
#     'date': datetime.datetime(2024, 7, 4, 11, 40, 42, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': None,
#     'duration_unit': None},
#    {'name': 'HKWorkoutEventTypeMotionPaused',
#     'date': datetime.datetime(2024, 7, 4, 11, 40, 52, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': None,
#     'duration_unit': None},
#    {'name': 'HKWorkoutEventTypeMotionResumed',
#     'date': datetime.datetime(2024, 7, 4, 11, 40, 58, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': None,
#     'duration_unit': None},
#    {'name': 'HKWorkoutEventTypeMotionPaused',
#     'date': datetime.datetime(2024, 7, 4, 11, 41, 1, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': None,
#     'duration_unit': None},
#    {'name': 'HKWorkoutEventTypeMotionResumed',
#     'date': datetime.datetime(2024, 7, 4, 11, 41, 27, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': None,
#     'duration_unit': None},
#    {'name': 'HKWorkoutEventTypeMotionPaused',
#     'date': datetime.datetime(2024, 7, 4, 11, 41, 38, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': None,
#     'duration_unit': None}],
#   'statistics': [{'name': 'HKQuantityTypeIdentifierStepCount',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 4, 11, 28, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 4, 11, 42, 54, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 1730.0,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierRunningGroundContactTime',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 4, 11, 28, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 4, 11, 42, 54, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 285.955,
#     'min': 199.0,
#     'max': 338.0,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierRunningPower',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 4, 11, 28, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 4, 11, 42, 54, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 190.712,
#     'min': 60.0,
#     'max': 307.0,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierActiveEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 4, 11, 28, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 4, 11, 42, 54, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 129.207,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierBasalEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 4, 11, 28, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 4, 11, 42, 54, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 25.6247,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierRunningVerticalOscillation',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 4, 11, 28, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 4, 11, 42, 54, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 10.7852,
#     'min': 8.6,
#     'max': 11.5,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierRunningSpeed',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 4, 11, 28, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 4, 11, 42, 54, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 4.81245,
#     'min': 1.07931,
#     'max': 7.73517,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierRunningStrideLength',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 4, 11, 28, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 4, 11, 42, 54, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 0.809052,
#     'min': 0.45,
#     'max': 1.18,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierDistanceWalkingRunning',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 4, 11, 28, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 4, 11, 42, 54, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 0.954367,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierHeartRate',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 4, 11, 28, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 4, 11, 42, 54, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 143.376,
#     'min': 102.0,
#     'max': 166.0,
#     'unit': None}],
#   'route': {'file_path': '/workout-routes/route_2024-07-04_11.42am.gpx',
#    'file_name': 'route_2024-07-04_11.42am.gpx',
#    'metadata': [{'key': 'HKMetadataKeySyncVersion', 'value': '2'},
#     {'key': 'HKMetadataKeySyncIdentifier',
#      'value': '5FF1FD17-B034-4A7B-BE8A-2887B563AD61'}]}},
#  {'name': 'HKWorkoutActivityTypeTraditionalStrengthTraining',
#   'source_id': 'CHARLIESAPPLEWATCH',
#   'created_at': datetime.datetime(2024, 7, 4, 12, 43, 4, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start': datetime.datetime(2024, 7, 4, 11, 43, 4, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start_date_str': '2024-07-04',
#   'end': datetime.datetime(2024, 7, 4, 12, 43, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'unit': None,
#   'value': None,
#   'heartrate_variability': [],
#   'metadata': [{'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKAverageMETs', 'value': '10.0325 kcal/hrÂ·kg'},
#    {'key': 'HKWeatherTemperature', 'value': '89.132 degF'},
#    {'key': 'HKWeatherHumidity', 'value': '6800 %'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKAverageMETs', 'value': '10.0325 kcal/hrÂ·kg'},
#    {'key': 'HKWeatherTemperature', 'value': '89.132 degF'},
#    {'key': 'HKWeatherHumidity', 'value': '6800 %'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'}],
#   'duration': 59.94751300017039,
#   'duration_unit': 'min',
#   'distance': None,
#   'distance_unit': 'mi',
#   'energy_burned': 756.361,
#   'energy_burned_unit': 'Cal',
#   'flights_climbed': None,
#   'swimming_strokes': None,
#   'events': [],
#   'statistics': [{'name': 'HKQuantityTypeIdentifierActiveEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 4, 11, 43, 4, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 4, 12, 43, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 756.361,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierHeartRate',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 4, 11, 43, 4, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 4, 12, 43, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 146.314,
#     'min': 110.0,
#     'max': 186.0,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierBasalEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 4, 11, 43, 4, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 4, 12, 43, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 110.677,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None}],
#   'route': None},
#  {'name': 'HKWorkoutActivityTypeWalking',
#   'source_id': 'CHARLIESAPPLEWATCH',
#   'created_at': datetime.datetime(2024, 7, 4, 13, 22, 38, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start': datetime.datetime(2024, 7, 4, 13, 1, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start_date_str': '2024-07-04',
#   'end': datetime.datetime(2024, 7, 4, 13, 22, 36, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'unit': None,
#   'value': None,
#   'heartrate_variability': [],
#   'metadata': [{'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKElevationAscended', 'value': '200 cm'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKWeatherHumidity', 'value': '6000 %'},
#    {'key': 'HKWeatherTemperature', 'value': '92.156 degF'},
#    {'key': 'HKAverageMETs', 'value': '4.90575 kcal/hrÂ·kg'},
#    {'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKElevationAscended', 'value': '200 cm'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKWeatherHumidity', 'value': '6000 %'},
#    {'key': 'HKWeatherTemperature', 'value': '92.156 degF'},
#    {'key': 'HKAverageMETs', 'value': '4.90575 kcal/hrÂ·kg'}],
#   'duration': 21.5917185485363,
#   'duration_unit': 'min',
#   'distance': 1.00043,
#   'distance_unit': 'mi',
#   'energy_burned': 112.991,
#   'energy_burned_unit': 'Cal',
#   'flights_climbed': None,
#   'swimming_strokes': None,
#   'events': [{'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 4, 13, 1, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 11.71471563776334,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 4, 13, 1, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 21.47502494255702,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 4, 13, 12, 43, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 9.76519073843956,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 4, 13, 22, 29, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 0.004881433645884196,
#     'duration_unit': 'min'}],
#   'statistics': [{'name': 'HKQuantityTypeIdentifierDistanceWalkingRunning',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 4, 13, 1, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 4, 13, 22, 36, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 1.00043,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierBasalEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 4, 13, 1, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 4, 13, 22, 36, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 39.9999,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierHeartRate',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 4, 13, 1, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 4, 13, 22, 36, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 115.815,
#     'min': 103.0,
#     'max': 125.0,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierActiveEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 4, 13, 1, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 4, 13, 22, 36, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 112.991,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None}],
#   'route': {'file_path': '/workout-routes/route_2024-07-04_1.22pm.gpx',
#    'file_name': 'route_2024-07-04_1.22pm.gpx',
#    'metadata': [{'key': 'HKMetadataKeySyncVersion', 'value': '2'},
#     {'key': 'HKMetadataKeySyncIdentifier',
#      'value': 'E4E48A14-25F8-456E-9A12-B607F97F7657'}]}},
#  {'name': 'HKWorkoutActivityTypePickleball',
#   'source_id': 'CHARLIESAPPLEWATCH',
#   'created_at': datetime.datetime(2024, 7, 6, 9, 50, 56, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start': datetime.datetime(2024, 7, 6, 7, 24, 24, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start_date_str': '2024-07-06',
#   'end': datetime.datetime(2024, 7, 6, 9, 50, 48, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'unit': None,
#   'value': None,
#   'heartrate_variability': [],
#   'metadata': [{'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKAverageMETs', 'value': '10.8983 kcal/hrÂ·kg'},
#    {'key': 'HKWeatherTemperature', 'value': '77.612 degF'},
#    {'key': 'HKWeatherHumidity', 'value': '9400 %'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKAverageMETs', 'value': '10.8983 kcal/hrÂ·kg'},
#    {'key': 'HKWeatherTemperature', 'value': '77.612 degF'},
#    {'key': 'HKWeatherHumidity', 'value': '9400 %'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'}],
#   'duration': 146.4101535995801,
#   'duration_unit': 'min',
#   'distance': None,
#   'distance_unit': 'mi',
#   'energy_burned': 1999.39,
#   'energy_burned_unit': 'Cal',
#   'flights_climbed': None,
#   'swimming_strokes': None,
#   'events': [],
#   'statistics': [{'name': 'HKQuantityTypeIdentifierActiveEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 6, 7, 24, 24, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 6, 9, 50, 48, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 1999.39,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierHeartRate',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 6, 7, 24, 24, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 6, 9, 50, 48, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 158.516,
#     'min': 79.0,
#     'max': 194.0,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierBasalEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 6, 7, 24, 24, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 6, 9, 50, 48, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 268.373,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None}],
#   'route': None},
#  {'name': 'HKWorkoutActivityTypeWalking',
#   'source_id': 'CHARLIESAPPLEWATCH',
#   'created_at': datetime.datetime(2024, 7, 8, 7, 48, 41, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start': datetime.datetime(2024, 7, 8, 7, 29, 37, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start_date_str': '2024-07-08',
#   'end': datetime.datetime(2024, 7, 8, 7, 48, 39, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'unit': None,
#   'value': None,
#   'heartrate_variability': [],
#   'metadata': [{'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKWeatherHumidity', 'value': '9100 %'},
#    {'key': 'HKWeatherTemperature', 'value': '79.592 degF'},
#    {'key': 'HKAverageMETs', 'value': '4.00445 kcal/hrÂ·kg'},
#    {'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKWeatherHumidity', 'value': '9100 %'},
#    {'key': 'HKWeatherTemperature', 'value': '79.592 degF'},
#    {'key': 'HKAverageMETs', 'value': '4.00445 kcal/hrÂ·kg'}],
#   'duration': 19.03205168445905,
#   'duration_unit': 'min',
#   'distance': 0.940996,
#   'distance_unit': 'mi',
#   'energy_burned': 71.9838,
#   'energy_burned_unit': 'Cal',
#   'flights_climbed': None,
#   'swimming_strokes': None,
#   'events': [{'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 8, 7, 29, 37, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 12.28317853411039,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 8, 7, 41, 54, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 6.675175009171168,
#     'duration_unit': 'min'}],
#   'statistics': [{'name': 'HKQuantityTypeIdentifierDistanceWalkingRunning',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 8, 7, 29, 37, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 8, 7, 48, 39, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 0.940996,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierBasalEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 8, 7, 29, 37, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 8, 7, 48, 39, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 34.7162,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierHeartRate',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 8, 7, 29, 37, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 8, 7, 48, 39, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 85.7002,
#     'min': 79.0,
#     'max': 93.0,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierActiveEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 8, 7, 29, 37, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 8, 7, 48, 39, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 71.9838,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None}],
# ...
#     'sum': 42.691,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None}],
#   'route': {'file_path': '/workout-routes/route_2024-07-19_12.28pm.gpx',
#    'file_name': 'route_2024-07-19_12.28pm.gpx',
#    'metadata': [{'key': 'HKMetadataKeySyncVersion', 'value': '2'},
#     {'key': 'HKMetadataKeySyncIdentifier',
#      'value': 'A4F48ABC-CFBA-4A3A-B47B-CB88841ED7F8'}]}},
#  {'name': 'HKWorkoutActivityTypeRunning',
#   'source_id': 'CHARLIESAPPLEWATCH',
#   'created_at': datetime.datetime(2024, 7, 19, 12, 59, 19, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start': datetime.datetime(2024, 7, 19, 12, 28, 33, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start_date_str': '2024-07-19',
#   'end': datetime.datetime(2024, 7, 19, 12, 59, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'unit': None,
#   'value': None,
#   'heartrate_variability': [],
#   'metadata': [{'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKWeatherHumidity', 'value': '6400 %'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKWeatherTemperature', 'value': '90.932 degF'},
#    {'key': 'HKAverageMETs', 'value': '7.31828 kcal/hrÂ·kg'},
#    {'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKWeatherHumidity', 'value': '6400 %'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKWeatherTemperature', 'value': '90.932 degF'},
#    {'key': 'HKAverageMETs', 'value': '7.31828 kcal/hrÂ·kg'}],
#   'duration': 30.67030973434448,
#   'duration_unit': 'min',
#   'distance': 2.01834,
#   'distance_unit': 'mi',
#   'energy_burned': 264.71,
#   'energy_burned_unit': 'Cal',
#   'flights_climbed': None,
#   'swimming_strokes': None,
#   'events': [{'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 19, 12, 28, 33, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 8.441350781917572,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 19, 12, 28, 33, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 14.11736531058947,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeMotionResumed',
#     'date': datetime.datetime(2024, 7, 19, 12, 28, 33, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': None,
#     'duration_unit': None},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 19, 12, 36, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 9.503510826826096,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 19, 12, 42, 40, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 16.12820924719175,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 19, 12, 46, 30, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 10.07278918822606,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 19, 12, 56, 34, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 2.572899103164673,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 19, 12, 58, 48, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 0.344975342353185,
#     'duration_unit': 'min'}],
#   'statistics': [{'name': 'HKQuantityTypeIdentifierStepCount',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 19, 12, 28, 33, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 19, 12, 59, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 4455.0,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierRunningGroundContactTime',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 19, 12, 28, 33, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 19, 12, 59, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 306.633,
#     'min': 264.0,
#     'max': 349.0,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierRunningPower',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 19, 12, 28, 33, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 19, 12, 59, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 159.108,
#     'min': 64.0,
#     'max': 231.0,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierActiveEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 19, 12, 28, 33, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 19, 12, 59, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 264.71,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierBasalEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 19, 12, 28, 33, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 19, 12, 59, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 56.722,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierRunningVerticalOscillation',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 19, 12, 28, 33, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 19, 12, 59, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 10.8581,
#     'min': 9.8,
#     'max': 11.7,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierRunningSpeed',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 19, 12, 28, 33, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 19, 12, 59, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 3.98327,
#     'min': 0.785459,
#     'max': 5.74908,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierRunningStrideLength',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 19, 12, 28, 33, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 19, 12, 59, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 0.737133,
#     'min': 0.65,
#     'max': 0.9,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierDistanceWalkingRunning',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 19, 12, 28, 33, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 19, 12, 59, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 2.01834,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierHeartRate',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 19, 12, 28, 33, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 19, 12, 59, 13, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 154.613,
#     'min': 106.0,
#     'max': 167.0,
#     'unit': None}],
#   'route': {'file_path': '/workout-routes/route_2024-07-19_12.59pm.gpx',
#    'file_name': 'route_2024-07-19_12.59pm.gpx',
#    'metadata': [{'key': 'HKMetadataKeySyncVersion', 'value': '2'},
#     {'key': 'HKMetadataKeySyncIdentifier',
#      'value': '3B139E04-AA7F-4AC7-AE89-3EE416D8F020'}]}},
#  {'name': 'HKWorkoutActivityTypeWalking',
#   'source_id': 'CHARLIESAPPLEWATCH',
#   'created_at': datetime.datetime(2024, 7, 19, 13, 31, 31, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start': datetime.datetime(2024, 7, 19, 12, 59, 21, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start_date_str': '2024-07-19',
#   'end': datetime.datetime(2024, 7, 19, 13, 31, 28, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'unit': None,
#   'value': None,
#   'heartrate_variability': [],
#   'metadata': [{'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKWeatherHumidity', 'value': '6300 %'},
#    {'key': 'HKWeatherTemperature', 'value': '91.868 degF'},
#    {'key': 'HKAverageMETs', 'value': '5.52585 kcal/hrÂ·kg'},
#    {'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKWeatherHumidity', 'value': '6300 %'},
#    {'key': 'HKWeatherTemperature', 'value': '91.868 degF'},
#    {'key': 'HKAverageMETs', 'value': '5.52585 kcal/hrÂ·kg'}],
#   'duration': 32.10396011670431,
#   'duration_unit': 'min',
#   'distance': 1.61379,
#   'distance_unit': 'mi',
#   'energy_burned': 195.25,
#   'energy_burned_unit': 'Cal',
#   'flights_climbed': None,
#   'swimming_strokes': None,
#   'events': [{'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 19, 12, 59, 21, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 11.22608071366946,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 19, 12, 59, 21, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 18.83621989091237,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 19, 13, 10, 35, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 12.89040483832359,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 19, 13, 18, 12, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 13.21115927497546,
#     'duration_unit': 'min'},
#    {'name': 'HKWorkoutEventTypeSegment',
#     'date': datetime.datetime(2024, 7, 19, 13, 23, 28, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'duration': 7.930893613894781,
#     'duration_unit': 'min'}],
#   'statistics': [{'name': 'HKQuantityTypeIdentifierDistanceWalkingRunning',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 19, 12, 59, 21, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 19, 13, 31, 28, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 1.61379,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierBasalEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 19, 12, 59, 21, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 19, 13, 31, 28, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 59.5601,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierHeartRate',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 19, 12, 59, 21, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 19, 13, 31, 28, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 139.192,
#     'min': 127.0,
#     'max': 163.0,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierActiveEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 19, 12, 59, 21, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 19, 13, 31, 28, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 195.25,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None}],
#   'route': {'file_path': '/workout-routes/route_2024-07-19_1.31pm.gpx',
#    'file_name': 'route_2024-07-19_1.31pm.gpx',
#    'metadata': [{'key': 'HKMetadataKeySyncVersion', 'value': '2'},
#     {'key': 'HKMetadataKeySyncIdentifier',
#      'value': 'DB2FED6E-6E87-42D4-9128-9FDC50D1552F'}]}},
#  {'name': 'HKWorkoutActivityTypeWalking',
#   'source_id': 'CHARLIESAPPLEWATCH',
#   'created_at': datetime.datetime(2024, 7, 20, 14, 44, 47, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start': datetime.datetime(2024, 7, 20, 14, 24, 45, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'start_date_str': '2024-07-20',
#   'end': datetime.datetime(2024, 7, 20, 14, 44, 45, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#   'unit': None,
#   'value': None,
#   'heartrate_variability': [],
#   'metadata': [{'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKAverageMETs', 'value': '3.26862 kcal/hrÂ·kg'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKElevationAscended', 'value': '2431 cm'},
#    {'key': 'HKIndoorWorkout', 'value': '0'},
#    {'key': 'HKAverageMETs', 'value': '3.26862 kcal/hrÂ·kg'},
#    {'key': 'HKTimeZone', 'value': 'America/New_York'},
#    {'key': 'HKElevationAscended', 'value': '2431 cm'}],
#   'duration': 19.99780801733335,
#   'duration_unit': 'min',
#   'distance': 0.383135,
#   'distance_unit': 'mi',
#   'energy_burned': 62.3564,
#   'energy_burned_unit': 'Cal',
#   'flights_climbed': None,
#   'swimming_strokes': None,
#   'events': [],
#   'statistics': [{'name': 'HKQuantityTypeIdentifierDistanceWalkingRunning',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 20, 14, 24, 45, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 20, 14, 44, 45, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 0.383135,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierBasalEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 20, 14, 24, 45, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 20, 14, 44, 45, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 37.046,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierHeartRate',
#     'type': 'AVG',
#     'start_date': datetime.datetime(2024, 7, 20, 14, 24, 45, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 20, 14, 44, 45, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': None,
#     'average': 89.2425,
#     'min': 74.0,
#     'max': 108.0,
#     'unit': None},
#    {'name': 'HKQuantityTypeIdentifierActiveEnergyBurned',
#     'type': 'SUM',
#     'start_date': datetime.datetime(2024, 7, 20, 14, 24, 45, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'end_date': datetime.datetime(2024, 7, 20, 14, 44, 45, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#     'sum': 62.3564,
#     'average': None,
#     'min': None,
#     'max': None,
#     'unit': None}],
#   'route': {'file_path': '/workout-routes/route_2024-07-20_2.44pm.gpx',
#    'file_name': 'route_2024-07-20_2.44pm.gpx',
#    'metadata': [{'key': 'HKMetadataKeySyncVersion', 'value': '2'},
#     {'key': 'HKMetadataKeySyncIdentifier',
#      'value': '5612AD43-6C8F-415E-8510-A3651AFDC674'}]}}]

# %%
w = Workout(**data['Workout'][-6])
w.get_statistic('HKQuantityTypeIdentifierActiveEnergyBurned')
w.__dict__
# Out:
# {'name': 'HKQuantityTypeIdentifierDistanceWalkingRunning', 'type': 'SUM', 'start_date': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), 'end_date': datetime.datetime(2024, 7, 17, 13, 30, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), 'sum': 3.4201, 'average': None, 'min': None, 'max': None, 'unit': None}
# {'name': 'HKQuantityTypeIdentifierActiveEnergyBurned', 'type': 'SUM', 'start_date': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), 'end_date': datetime.datetime(2024, 7, 17, 13, 30, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), 'sum': 436.867, 'average': None, 'min': None, 'max': None, 'unit': None}
# {'name': 'HKQuantityTypeIdentifierActiveEnergyBurned', 'type': 'SUM', 'start_date': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), 'end_date': datetime.datetime(2024, 7, 17, 13, 30, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), 'sum': 436.867, 'average': None, 'min': None, 'max': None, 'unit': None}
# {'name': 'HKWorkoutActivityTypeRunning',
#  'source_id': 'CHARLIESAPPLEWATCH9_6_3',
#  'created_at': datetime.datetime(2024, 7, 17, 13, 31, 7, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#  'start': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#  'start_date_str': '2024-07-17',
#  'end': datetime.datetime(2024, 7, 17, 13, 30, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#  'unit': None,
#  'value': None,
#  'heartrate_variability': [],
#  'metadata': [{'key': 'HKIndoorWorkout', 'value': '0'},
#   {'key': 'HKElevationAscended', 'value': '207 cm'},
#   {'key': 'HKWeatherHumidity', 'value': '6600 %'},
#   {'key': 'HKTimeZone', 'value': 'America/New_York'},
#   {'key': 'HKWeatherTemperature', 'value': '89.456 degF'},
#   {'key': 'HKAverageMETs', 'value': '6.99379 kcal/hrÂ·kg'},
#   {'key': 'HKIndoorWorkout', 'value': '0'},
#   {'key': 'HKElevationAscended', 'value': '207 cm'},
#   {'key': 'HKWeatherHumidity', 'value': '6600 %'},
#   {'key': 'HKTimeZone', 'value': 'America/New_York'},
#   {'key': 'HKWeatherTemperature', 'value': '89.456 degF'},
#   {'key': 'HKAverageMETs', 'value': '6.99379 kcal/hrÂ·kg'}],
#  'duration': 53.09000549912453,
#  'duration_unit': 'min',
#  'distance': 3.4201,
#  'distance_unit': 'mi',
#  'energy_burned': 436.867,
#  'energy_burned_unit': 'Cal',
#  'flights_climbed': None,
#  'swimming_strokes': None,
#  'events': [{'name': 'HKWorkoutEventTypeSegment',
#    'date': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'duration': 8.986495371659597,
#    'duration_unit': 'min'},
#   {'name': 'HKWorkoutEventTypeSegment',
#    'date': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'duration': 15.75660931865374,
#    'duration_unit': 'min'},
#   {'name': 'HKWorkoutEventTypeMotionResumed',
#    'date': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'duration': None,
#    'duration_unit': None},
#   {'name': 'HKWorkoutEventTypeMotionPaused',
#    'date': datetime.datetime(2024, 7, 17, 12, 44, 8, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'duration': None,
#    'duration_unit': None},
#   {'name': 'HKWorkoutEventTypeMotionResumed',
#    'date': datetime.datetime(2024, 7, 17, 12, 44, 14, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'duration': None,
#    'duration_unit': None},
#   {'name': 'HKWorkoutEventTypeSegment',
#    'date': datetime.datetime(2024, 7, 17, 12, 46, 52, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'duration': 10.2683307826519,
#    'duration_unit': 'min'},
#   {'name': 'HKWorkoutEventTypeMotionPaused',
#    'date': datetime.datetime(2024, 7, 17, 12, 50, 29, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'duration': None,
#    'duration_unit': None},
#   {'name': 'HKWorkoutEventTypeMotionResumed',
#    'date': datetime.datetime(2024, 7, 17, 12, 51, 2, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'duration': None,
#    'duration_unit': None},
#   {'name': 'HKWorkoutEventTypeSegment',
#    'date': datetime.datetime(2024, 7, 17, 12, 53, 39, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'duration': 15.10292791922887,
#    'duration_unit': 'min'},
#   {'name': 'HKWorkoutEventTypeSegment',
#    'date': datetime.datetime(2024, 7, 17, 12, 57, 9, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'duration': 9.467355855305989,
#    'duration_unit': 'min'},
#   {'name': 'HKWorkoutEventTypeSegment',
#    'date': datetime.datetime(2024, 7, 17, 13, 6, 37, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'duration': 9.796632570028304,
#    'duration_unit': 'min'},
#   {'name': 'HKWorkoutEventTypeSegment',
#    'date': datetime.datetime(2024, 7, 17, 13, 8, 45, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'duration': 15.62858588695526,
#    'duration_unit': 'min'},
#   {'name': 'HKWorkoutEventTypeSegment',
#    'date': datetime.datetime(2024, 7, 17, 13, 16, 24, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'duration': 9.787862988313039,
#    'duration_unit': 'min'},
#   {'name': 'HKWorkoutEventTypeSegment',
#    'date': datetime.datetime(2024, 7, 17, 13, 24, 23, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'duration': 6.55049283305804,
#    'duration_unit': 'min'},
#   {'name': 'HKWorkoutEventTypeSegment',
#    'date': datetime.datetime(2024, 7, 17, 13, 26, 12, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'duration': 4.731938389937083,
#    'duration_unit': 'min'}],
#  'statistics': [{'name': 'HKQuantityTypeIdentifierStepCount',
#    'type': 'SUM',
#    'start_date': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'end_date': datetime.datetime(2024, 7, 17, 13, 30, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'sum': 6906.0,
#    'average': None,
#    'min': None,
#    'max': None,
#    'unit': None},
#   {'name': 'HKQuantityTypeIdentifierRunningGroundContactTime',
#    'type': 'AVG',
#    'start_date': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'end_date': datetime.datetime(2024, 7, 17, 13, 30, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'sum': None,
#    'average': 312.776,
#    'min': 218.0,
#    'max': 354.0,
#    'unit': None},
#   {'name': 'HKQuantityTypeIdentifierRunningPower',
#    'type': 'AVG',
#    'start_date': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'end_date': datetime.datetime(2024, 7, 17, 13, 30, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'sum': None,
#    'average': 148.396,
#    'min': 61.0,
#    'max': 342.0,
#    'unit': None},
#   {'name': 'HKQuantityTypeIdentifierActiveEnergyBurned',
#    'type': 'SUM',
#    'start_date': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'end_date': datetime.datetime(2024, 7, 17, 13, 30, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'sum': 436.867,
#    'average': None,
#    'min': None,
#    'max': None,
#    'unit': None},
#   {'name': 'HKQuantityTypeIdentifierBasalEnergyBurned',
#    'type': 'SUM',
#    'start_date': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'end_date': datetime.datetime(2024, 7, 17, 13, 30, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'sum': 98.576,
#    'average': None,
#    'min': None,
#    'max': None,
#    'unit': None},
#   {'name': 'HKQuantityTypeIdentifierRunningVerticalOscillation',
#    'type': 'AVG',
#    'start_date': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'end_date': datetime.datetime(2024, 7, 17, 13, 30, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'sum': None,
#    'average': 10.7184,
#    'min': 9.7,
#    'max': 12.0,
#    'unit': None},
#   {'name': 'HKQuantityTypeIdentifierRunningSpeed',
#    'type': 'AVG',
#    'start_date': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'end_date': datetime.datetime(2024, 7, 17, 13, 30, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'sum': None,
#    'average': 3.90708,
#    'min': 0.562266,
#    'max': 8.61155,
#    'unit': None},
#   {'name': 'HKQuantityTypeIdentifierRunningStrideLength',
#    'type': 'AVG',
#    'start_date': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'end_date': datetime.datetime(2024, 7, 17, 13, 30, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'sum': None,
#    'average': 0.751387,
#    'min': 0.54,
#    'max': 1.09,
#    'unit': None},
#   {'name': 'HKQuantityTypeIdentifierDistanceWalkingRunning',
#    'type': 'SUM',
#    'start_date': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'end_date': datetime.datetime(2024, 7, 17, 13, 30, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'sum': 3.4201,
#    'average': None,
#    'min': None,
#    'max': None,
#    'unit': None},
#   {'name': 'HKQuantityTypeIdentifierHeartRate',
#    'type': 'AVG',
#    'start_date': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'end_date': datetime.datetime(2024, 7, 17, 13, 30, 59, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))),
#    'sum': None,
#    'average': 148.971,
#    'min': 122.0,
#    'max': 179.0,
#    'unit': None}],
#  'route': {'file_path': '/workout-routes/route_2024-07-17_1.30pm.gpx',
#   'file_name': 'route_2024-07-17_1.30pm.gpx',
#   'metadata': [{'key': 'HKMetadataKeySyncVersion', 'value': '2'},
#    {'key': 'HKMetadataKeySyncIdentifier',
#     'value': 'D09544F2-5EE4-4295-8C81-EC0F8147B13A'}]}}

# %%
file = ROOT_DIR + 'export.xml'

data = HealthData.read(
    file,
    include_me=True,
    include_activity_summaries=True,
    include_correlations=False,
    include_records=True,
    include_workouts=True,
)

print(data.me.biological_sex)
print(f"{len(data.activity_summaries)} activity records")
print(f"{len(data.correlations)} correlations")
print(f"{len(data.records)} records")
print(f"{len(data.workouts)} workouts")
# Out:
# HKBiologicalSexMale
# 539 activity records
# 0 correlations
# 1732268 records
# 545 workouts

# %%
day = datetime.datetime.date(datetime.datetime(2024,7,17))

config = data.me.__dict__
day_activity_summary = [summary for summary in data.activity_summaries if summary.date.date() == day]
day_workouts = [workout for workout in data.workouts if workout.start.date() == day]
day_records = [record for record in data.records if record.start.date() == day]

# %%
config
# Out:
# {'date_of_birth': datetime.datetime(1998, 4, 11, 0, 0),
#  'biological_sex': 'HKBiologicalSexMale',
#  'blood_type': 'HKBloodTypeNotSet',
#  'skin_type': 'HKFitzpatrickSkinTypeNotSet',
#  'wheelchair_use': None}

# %%
day_activity_summary[0].__dict__
# Out:
# {'date': datetime.datetime(2024, 7, 17, 0, 0),
#  'active_energy_burned': 3227.75,
#  'active_energy_burned_goal': 500.0,
#  'active_energy_burned_unit': 'Cal',
#  'exercise_time': 240.0,
#  'exercise_time_goal': 45.0,
#  'stand_hours': 13.0,
#  'stand_hours_goal': 8.0}

# %%
workout = day_workouts[1].__dict__

workout_start_time = workout['start']
workout_end_time = workout['end']
print(workout)
workout_records = [record for record in data.records if record.start >= workout_start_time and record.end <= workout_end_time]
workout_records_df = pd.DataFrame([record.__dict__ for record in workout_records])
workout_records_df
# Out:
# {'name': 'HKWorkoutActivityTypeRunning', 'source': 'Charlieâ€™s AppleÂ\xa0Watch', 'created_at': datetime.datetime(2024, 7, 17, 13, 31, 7, tzinfo=tzoffset(None, -14400)), 'start': datetime.datetime(2024, 7, 17, 12, 37, 53, tzinfo=tzoffset(None, -14400)), 'end': datetime.datetime(2024, 7, 17, 13, 30, 59, tzinfo=tzoffset(None, -14400)), 'metadata': [HKIndoorWorkout: 0, HKElevationAscended: 207 cm, HKWeatherHumidity: 6600 %, HKTimeZone: America/New_York, HKWeatherTemperature: 89.456 degF, HKAverageMETs: 6.99379 kcal/hrÂ·kg, HKIndoorWorkout: 0, HKElevationAscended: 207 cm, HKWeatherHumidity: 6600 %, HKTimeZone: America/New_York, HKWeatherTemperature: 89.456 degF, HKAverageMETs: 6.99379 kcal/hrÂ·kg], 'duration': 53.09000549912453, 'duration_unit': 'min', 'distance': 0.0, 'distance_unit': None, 'energy_burned': 0.0, 'energy_burned_unit': None, 'flights_climbed': 0.0, 'swimming_strokes': 0.0}
#                                       name                    source  \
# 0        HKQuantityTypeIdentifierHeartRate  Charlieâ€™s AppleÂ Watch
# 1        HKQuantityTypeIdentifierHeartRate  Charlieâ€™s AppleÂ Watch
# 2        HKQuantityTypeIdentifierHeartRate  Charlieâ€™s AppleÂ Watch
# 3        HKQuantityTypeIdentifierHeartRate  Charlieâ€™s AppleÂ Watch
# 4        HKQuantityTypeIdentifierHeartRate  Charlieâ€™s AppleÂ Watch
# ...                                    ...                       ...
# 9052  HKQuantityTypeIdentifierRunningSpeed  Charlieâ€™s AppleÂ Watch
# 9053  HKQuantityTypeIdentifierRunningSpeed  Charlieâ€™s AppleÂ Watch
# 9054  HKQuantityTypeIdentifierRunningSpeed  Charlieâ€™s AppleÂ Watch
# 9055  HKQuantityTypeIdentifierRunningSpeed  Charlieâ€™s AppleÂ Watch
# 9056  HKQuantityTypeIdentifierRunningSpeed  Charlieâ€™s AppleÂ Watch
#
#                     created_at                     start  \
# 0    2024-07-17 12:37:55-04:00 2024-07-17 12:37:53-04:00
# 1    2024-07-17 12:38:00-04:00 2024-07-17 12:37:55-04:00
# 2    2024-07-17 12:38:05-04:00 2024-07-17 12:38:01-04:00
# 3    2024-07-17 12:38:10-04:00 2024-07-17 12:38:04-04:00
# 4    2024-07-17 12:38:15-04:00 2024-07-17 12:38:10-04:00
# ...                        ...                       ...
# 9052 2024-07-17 13:30:48-04:00 2024-07-17 13:30:45-04:00
# 9053 2024-07-17 13:30:51-04:00 2024-07-17 13:30:48-04:00
# 9054 2024-07-17 13:30:52-04:00 2024-07-17 13:30:50-04:00
# 9055 2024-07-17 13:30:56-04:00 2024-07-17 13:30:53-04:00
# 9056 2024-07-17 13:30:58-04:00 2024-07-17 13:30:56-04:00
#
#                            end                                  metadata  \
# 0    2024-07-17 12:37:53-04:00  [HKMetadataKeyHeartRateMotionContext: 2]
# 1    2024-07-17 12:37:55-04:00  [HKMetadataKeyHeartRateMotionContext: 2]
# 2    2024-07-17 12:38:01-04:00  [HKMetadataKeyHeartRateMotionContext: 2]
# 3    2024-07-17 12:38:04-04:00  [HKMetadataKeyHeartRateMotionContext: 2]
# 4    2024-07-17 12:38:10-04:00  [HKMetadataKeyHeartRateMotionContext: 2]
# ...                        ...                                       ...
# 9052 2024-07-17 13:30:45-04:00                                        []
# 9053 2024-07-17 13:30:48-04:00                                        []
# 9054 2024-07-17 13:30:50-04:00                                        []
# 9055 2024-07-17 13:30:53-04:00                                        []
# 9056 2024-07-17 13:30:56-04:00                                        []
#
#            unit      value heart_rate
# 0     count/min  132.00000         []
# 1     count/min  132.00000         []
# 2     count/min  131.00000         []
# 3     count/min  129.00000         []
# 4     count/min  122.00000         []
# ...         ...        ...        ...
# 9052      mi/hr    6.87578         []
# 9053      mi/hr    6.91889         []
# 9054      mi/hr    7.05495         []
# 9055      mi/hr    7.12622         []
# 9056      mi/hr    6.98316         []
#
# [9057 rows x 9 columns]

# %%
workout_records_df.name.value_counts()
# Out:
# name
# HKQuantityTypeIdentifierBasalEnergyBurned                 1249
# HKQuantityTypeIdentifierActiveEnergyBurned                1249
# HKQuantityTypeIdentifierDistanceWalkingRunning            1234
# HKQuantityTypeIdentifierStepCount                         1233
# HKQuantityTypeIdentifierRunningSpeed                      1229
# HKQuantityTypeIdentifierRunningPower                      1227
# HKQuantityTypeIdentifierHeartRate                          637
# HKQuantityTypeIdentifierRunningStrideLength                310
# HKQuantityTypeIdentifierRunningVerticalOscillation         305
# HKQuantityTypeIdentifierRunningGroundContactTime           295
# HKQuantityTypeIdentifierAppleExerciseTime                   52
# HKQuantityTypeIdentifierAppleStandTime                      10
# HKQuantityTypeIdentifierWalkingSpeed                        10
# HKQuantityTypeIdentifierWalkingStepLength                   10
# HKQuantityTypeIdentifierWalkingDoubleSupportPercentage       5
# HKQuantityTypeIdentifierEnvironmentalAudioExposure           1
# HKQuantityTypeIdentifierVO2Max                               1
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Transform/Preprocess Data

# %%
import datetime 

## I want to create a config file and a data file that is either a parquet or a csv of all of the data that I have.

class UserConfig:
    def __init__(self, config):
        self.date_of_birth = config['date_of_birth']
        self.biological_sex = config['biological_sex']
        self.blood_type = config['blood_type']
        self.skin_type = config['skin_type']
        self.wheelchair_use = config['wheelchair_use']

    def __repr__(self):
        return f"UserConfig(date_of_birth={self.date_of_birth}, biological_sex={self.biological_sex}, blood_type={self.blood_type}, skin_type={self.skin_type}, wheelchair_use={self.wheelchair_use})"

# %%
day_records[-20].__dict__
# Out:
# {'name': 'HKCategoryTypeIdentifierAppleStandHour',
#  'source': 'Charlieâ€™s AppleÂ\xa0Watch',
#  'created_at': datetime.datetime(2024, 7, 17, 13, 0, 32, tzinfo=tzoffset(None, -14400)),
#  'start': datetime.datetime(2024, 7, 17, 13, 0, tzinfo=tzoffset(None, -14400)),
#  'end': datetime.datetime(2024, 7, 17, 14, 0, tzinfo=tzoffset(None, -14400)),
#  'metadata': [],
#  'unit': None,
#  'value': 0,
#  'heart_rate': []}

# %% [markdown]
# ## 4. Load data (as parquet)

# %% [markdown]
# ## 5. Build weekly calendar workout
